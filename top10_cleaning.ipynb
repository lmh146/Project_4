# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Read in the CSV files
top_2019 = pd.read_csv("Resources/top10s.csv")
decades = pd.read_csv("Resources/1921_2020.csv")

# %%
top_2019
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0               Train       neo mellow  2010   97    89    67  -4     8   80
# ...

# %%
decades
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
# ...

# %%
# Drop Extra Columns in the top19 df
dropped_df = top_2019.drop(columns = ['title', 'artist', 'top genre', 'Unnamed: 0'])
dropped_df
# Out:
#      year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    2010   97    89    67  -4     8   80  217     19     4   83
# 1    2010   87    93    75  -5    52   64  263     24    23   82
# 2    2010  120    84    76  -3    29   71  200     10    14   80
# 3    2010  119    92    70  -4     8   71  295      0     4   79
# 4    2010  109    84    64  -5     9   43  221      2     4   78
# ..    ...  ...   ...   ...  ..   ...  ...  ...    ...   ...  ...
# 598  2019  104    66    61  -7    20   16  176      1     3   75
# 599  2019   95    79    75  -6     7   61  206     21    12   75
# 600  2019  136    76    53  -5     9   65  260      7    34   70
# 601  2019  114    79    60  -6    42   24  217      1     7   69
# 602  2019  150    44    70  -9    13   23  213      6     6   67
#
# [603 rows x 11 columns]

# %%
# Rename Columns in top19 df
rename_top10 = dropped_df.rename(columns = {"bpm" : "tempo(BPM)",
                                         "nrgy" : "energy",
                                         "dnce" : "danceability",
                                         "dB" : "loudness",
                                         "live" : "liveness",
                                         "val" : "valence",
                                         "dur" : "duration",
                                         "acous" : "acousticness",
                                         "spch" : "speechiness",
                                         "pop" : "popularity"
                                        })
rename_top10
# Out:
#      year  tempo(BPM)  energy  danceability  loudness  liveness  valence  \
# 0    2010          97      89            67        -4         8       80
# 1    2010          87      93            75        -5        52       64
# 2    2010         120      84            76        -3        29       71
# 3    2010         119      92            70        -4         8       71
# 4    2010         109      84            64        -5         9       43
# ..    ...         ...     ...           ...       ...       ...      ...
# 598  2019         104      66            61        -7        20       16
# 599  2019          95      79            75        -6         7       61
# 600  2019         136      76            53        -5         9       65
# 601  2019         114      79            60        -6        42       24
# 602  2019         150      44            70        -9        13       23
#
#      duration  acousticness  speechiness  popularity
# ...

# %%
# Convert Duration Column
ms_duration = rename_top10['duration']*1000
rename_top10['duration'] = ms_duration

# %%
# Create a Function to Convert Columns to 0 - 1
def rescale(column):
    rescale_col = rename_top10[column]/100
    rename_top10[column] = rescale_col
    return rename_top10[column]

# %%
# Rescale All Columns
columns_rescale = ['acousticness', 'danceability', 'energy', 'liveness', 'valence', 'speechiness']
for col in columns_rescale:
    rescale(col)

# %%
# Drop Any Rows with NA values
rename_top10 = rename_top10.dropna(how = 'any')
rename_top10
# Out:
#      year  tempo(BPM)  energy  danceability  loudness  liveness  valence  \
# 0    2010          97    0.89          0.67        -4      0.08     0.80
# 1    2010          87    0.93          0.75        -5      0.52     0.64
# 2    2010         120    0.84          0.76        -3      0.29     0.71
# 3    2010         119    0.92          0.70        -4      0.08     0.71
# 4    2010         109    0.84          0.64        -5      0.09     0.43
# ..    ...         ...     ...           ...       ...       ...      ...
# 598  2019         104    0.66          0.61        -7      0.20     0.16
# 599  2019          95    0.79          0.75        -6      0.07     0.61
# 600  2019         136    0.76          0.53        -5      0.09     0.65
# 601  2019         114    0.79          0.60        -6      0.42     0.24
# 602  2019         150    0.44          0.70        -9      0.13     0.23
#
#      duration  acousticness  speechiness  popularity
# ...

# %%
cleaned_top10 = rename_top10[['acousticness','danceability','duration','energy','liveness','loudness','speechiness','tempo(BPM)','valence','year','popularity']]
cleaned_top10
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year  popularity
# 0           0.04          97     0.80  2010          83
# ...

# %%
cleaned_top10.to_csv("Resources/cleaned_top10.csv", index = False, header = True)
