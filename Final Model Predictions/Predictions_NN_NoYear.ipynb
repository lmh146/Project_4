# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

#  Import and read the charity_data.csv.
import pandas as pd 
top10_df = pd.read_csv("Resources/cleaned_top10.csv")
big_df = pd.read_csv("Resources/bigdf_binary.csv")

# %%
top10_df
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year  popularity
# 0           0.04          97     0.80  2010          83
# 1           0.23          87     0.64  2010          82
# 2           0.14         120     0.71  2010          80
# 3           0.04         119     0.71  2010          79
# 4           0.04         109     0.43  2010          78
# ..           ...         ...      ...   ...         ...
# 598         0.03         104     0.16  2019          75
# 599         0.12          95     0.61  2019          75
# 600         0.34         136     0.65  2019          70
# 601         0.07         114     0.24  2019          69
# 602         0.06         150     0.23  2019          67
#
# [603 rows x 11 columns]

# %%
big_df
# Out:
#         Unnamed: 0  Unnamed: 0.1  acousticness  danceability  duration  \
# 0                0             0        0.9950         0.708    158648
# 1                1             1        0.9940         0.379    282133
# 2                2             2        0.6040         0.749    104300
# 3                3             3        0.9950         0.781    180760
# 4                4             4        0.9900         0.210    687733
# ...            ...           ...           ...           ...       ...
# 169904      169904        169904        0.1730         0.875    163800
# 169905      169905        169905        0.0167         0.719    167468
# 169906      169906        169906        0.5380         0.514    180700
# 169907      169907        169907        0.0714         0.646    167308
# 169908      169908        169908        0.1090         0.512    214787
#
#         energy  instrumentalness  liveness  loudness  popularity  speechiness  \
# 0       0.1950          0.563000    0.1510   -12.428           0       0.0506
# 1       0.0135          0.901000    0.0763   -28.454           0       0.0462
# 2       0.2200          0.000000    0.1190   -19.924           0       0.9290
# 3       0.1300          0.887000    0.1110   -14.734           0       0.0926
# 4       0.2040          0.908000    0.0980   -16.829           0       0.0424
# ...        ...               ...       ...       ...         ...          ...
# 169904  0.4430          0.000032    0.0891    -7.461           1       0.1430
# 169905  0.3850          0.031300    0.1110   -10.907           1       0.0403
# 169906  0.5390          0.002330    0.1080    -9.332           1       0.1050
# 169907  0.7610          0.000000    0.2220    -2.557           1       0.0385
# 169908  0.4280          0.000000    0.1050    -7.387           1       0.0271
#
#         tempo(BPM)  valence  year
# 0          118.469   0.7790  1928
# 1           83.972   0.0767  1928
# 2          107.177   0.8800  1928
# 3          108.003   0.7200  1928
# 4           62.149   0.0693  1928
# ...            ...      ...   ...
# 169904     100.012   0.3060  2020
# 169905     128.000   0.2700  2020
# 169906     123.700   0.1530  2020
# 169907     129.916   0.4720  2020
# 169908      80.588   0.3660  2020
#
# [169909 rows x 14 columns]

# %%
# Drop from Big df
big_df = big_df.drop(columns = ['Unnamed: 0','Unnamed: 0.1','instrumentalness','year'])
big_df
# Out:
#         acousticness  danceability  duration  energy  liveness  loudness  \
# 0             0.9950         0.708    158648  0.1950    0.1510   -12.428
# 1             0.9940         0.379    282133  0.0135    0.0763   -28.454
# 2             0.6040         0.749    104300  0.2200    0.1190   -19.924
# 3             0.9950         0.781    180760  0.1300    0.1110   -14.734
# 4             0.9900         0.210    687733  0.2040    0.0980   -16.829
# ...              ...           ...       ...     ...       ...       ...
# 169904        0.1730         0.875    163800  0.4430    0.0891    -7.461
# 169905        0.0167         0.719    167468  0.3850    0.1110   -10.907
# 169906        0.5380         0.514    180700  0.5390    0.1080    -9.332
# 169907        0.0714         0.646    167308  0.7610    0.2220    -2.557
# 169908        0.1090         0.512    214787  0.4280    0.1050    -7.387
#
#         popularity  speechiness  tempo(BPM)  valence
# 0                0       0.0506     118.469   0.7790
# 1                0       0.0462      83.972   0.0767
# 2                0       0.9290     107.177   0.8800
# 3                0       0.0926     108.003   0.7200
# 4                0       0.0424      62.149   0.0693
# ...            ...          ...         ...      ...
# 169904           1       0.1430     100.012   0.3060
# 169905           1       0.0403     128.000   0.2700
# 169906           1       0.1050     123.700   0.1530
# 169907           1       0.0385     129.916   0.4720
# 169908           1       0.0271      80.588   0.3660
#
# [169909 rows x 10 columns]

# %%
# Drop Popularity
top10_df = top10_df.drop(columns = 'popularity')
top10_df
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year
# 0           0.04          97     0.80  2010
# 1           0.23          87     0.64  2010
# 2           0.14         120     0.71  2010
# 3           0.04         119     0.71  2010
# 4           0.04         109     0.43  2010
# ..           ...         ...      ...   ...
# 598         0.03         104     0.16  2019
# 599         0.12          95     0.61  2019
# 600         0.34         136     0.65  2019
# 601         0.07         114     0.24  2019
# 602         0.06         150     0.23  2019
#
# [603 rows x 10 columns]

# %%
# # Vectorize the dataset
# X = dataset.iloc[:, :-1].values #pulls everything up to but not including last column
# y = dataset.iloc[:, -1].values #pulls all data from last column

# %%
# Split our preprocessed data into our features and target arrays
y = big_df['popularity']
X = big_df.drop(['popularity'], axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim= number_input_features, name = 'layer1')) 

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=18, activation="relu", name = 'layer2'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation="tanh", name = 'layer3'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid")) 

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 20)                200
#
#  layer2 (Dense)              (None, 18)                378
#
#  layer3 (Dense)              (None, 10)                190
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 779
# Trainable params: 779
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Create a callback that saves the model's weights every 5 epochs
callback = tf.keras.callbacks.ModelCheckpoint(filepath = "Models/weights.{epoch:05d}.hdf5", save_freg = "epoch", period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 3983/3983 [==============================] - 4s 961us/step - loss: 0.4013 - accuracy: 0.8148
# Epoch 2/100
# 3983/3983 [==============================] - 4s 930us/step - loss: 0.3853 - accuracy: 0.8252
# Epoch 3/100
# 3983/3983 [==============================] - 4s 948us/step - loss: 0.3822 - accuracy: 0.8265
# Epoch 4/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3805 - accuracy: 0.8269
# Epoch 5/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3795 - accuracy: 0.8272
# Epoch 6/100
# 3983/3983 [==============================] - 4s 972us/step - loss: 0.3784 - accuracy: 0.8280
# Epoch 7/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3778 - accuracy: 0.8281
# Epoch 8/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3770 - accuracy: 0.8282
# Epoch 9/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3766 - accuracy: 0.8290
# Epoch 10/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3761 - accuracy: 0.8289
# Epoch 11/100
# 3983/3983 [==============================] - 4s 929us/step - loss: 0.3757 - accuracy: 0.8302
# Epoch 12/100
# 3983/3983 [==============================] - 4s 942us/step - loss: 0.3755 - accuracy: 0.8298
# Epoch 13/100
# 3983/3983 [==============================] - 4s 959us/step - loss: 0.3750 - accuracy: 0.8293
# Epoch 14/100
# 3983/3983 [==============================] - 4s 941us/step - loss: 0.3747 - accuracy: 0.8304
# Epoch 15/100
# 3983/3983 [==============================] - 4s 942us/step - loss: 0.3744 - accuracy: 0.8304
# Epoch 16/100
# 3983/3983 [==============================] - 4s 940us/step - loss: 0.3743 - accuracy: 0.8304
# Epoch 17/100
# 3983/3983 [==============================] - 4s 953us/step - loss: 0.3741 - accuracy: 0.8299
# Epoch 18/100
# 3983/3983 [==============================] - 4s 954us/step - loss: 0.3738 - accuracy: 0.8308
# Epoch 19/100
# 3983/3983 [==============================] - 4s 974us/step - loss: 0.3738 - accuracy: 0.8305
# Epoch 20/100
# 3983/3983 [==============================] - 4s 956us/step - loss: 0.3736 - accuracy: 0.8307
# Epoch 21/100
# 3983/3983 [==============================] - 4s 960us/step - loss: 0.3734 - accuracy: 0.8307
# Epoch 22/100
# 3983/3983 [==============================] - 4s 971us/step - loss: 0.3733 - accuracy: 0.8307
# Epoch 23/100
# 3983/3983 [==============================] - 4s 970us/step - loss: 0.3731 - accuracy: 0.8312
# Epoch 24/100
# 3983/3983 [==============================] - 4s 972us/step - loss: 0.3730 - accuracy: 0.8301
# Epoch 25/100
# 3983/3983 [==============================] - 4s 976us/step - loss: 0.3728 - accuracy: 0.8304
# Epoch 26/100
# 3983/3983 [==============================] - 4s 985us/step - loss: 0.3727 - accuracy: 0.8311
# Epoch 27/100
# 3983/3983 [==============================] - 4s 992us/step - loss: 0.3724 - accuracy: 0.8308
# Epoch 28/100
# 3983/3983 [==============================] - 4s 985us/step - loss: 0.3722 - accuracy: 0.8318
# Epoch 29/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3724 - accuracy: 0.8307
# Epoch 30/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3721 - accuracy: 0.8314
# Epoch 31/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3719 - accuracy: 0.8311
# Epoch 32/100
# 3983/3983 [==============================] - 4s 993us/step - loss: 0.3721 - accuracy: 0.8312
# Epoch 33/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3717 - accuracy: 0.8309
# Epoch 34/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3717 - accuracy: 0.8317
# Epoch 35/100
# 3983/3983 [==============================] - 4s 996us/step - loss: 0.3715 - accuracy: 0.8309
# Epoch 36/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3715 - accuracy: 0.8316
# Epoch 37/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3716 - accuracy: 0.8320
# Epoch 38/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3715 - accuracy: 0.8317
# Epoch 39/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3714 - accuracy: 0.8320
# Epoch 40/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3713 - accuracy: 0.8316
# Epoch 41/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3712 - accuracy: 0.8319
# Epoch 42/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3713 - accuracy: 0.8317
# Epoch 43/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3710 - accuracy: 0.8317
# Epoch 44/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3710 - accuracy: 0.8316
# Epoch 45/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3709 - accuracy: 0.8313
# Epoch 46/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3710 - accuracy: 0.8315
# Epoch 47/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3711 - accuracy: 0.8314
# Epoch 48/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3708 - accuracy: 0.8321
# Epoch 49/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3707 - accuracy: 0.8318
# Epoch 50/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3707 - accuracy: 0.8314
# Epoch 51/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3707 - accuracy: 0.8315
# Epoch 52/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3705 - accuracy: 0.8315
# Epoch 53/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3705 - accuracy: 0.8320
# Epoch 54/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3704 - accuracy: 0.8313
# Epoch 55/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3706 - accuracy: 0.8311
# Epoch 56/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3703 - accuracy: 0.8321
# Epoch 57/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3702 - accuracy: 0.8315
# Epoch 58/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3703 - accuracy: 0.8321
# Epoch 59/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3702 - accuracy: 0.8316
# Epoch 60/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3703 - accuracy: 0.8315
# Epoch 61/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3701 - accuracy: 0.8321
# Epoch 62/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3699 - accuracy: 0.8320
# Epoch 63/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3701 - accuracy: 0.8315
# Epoch 64/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3701 - accuracy: 0.8315
# Epoch 65/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3699 - accuracy: 0.8319
# Epoch 66/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3697 - accuracy: 0.8315
# Epoch 67/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3699 - accuracy: 0.8317
# Epoch 68/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3697 - accuracy: 0.8320
# Epoch 69/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3697 - accuracy: 0.8318
# Epoch 70/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3697 - accuracy: 0.8323
# Epoch 71/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3697 - accuracy: 0.8320
# Epoch 72/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3697 - accuracy: 0.8316
# Epoch 73/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3695 - accuracy: 0.8321
# Epoch 74/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3698 - accuracy: 0.8321
# Epoch 75/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3695 - accuracy: 0.8322
# Epoch 76/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3694 - accuracy: 0.8316
# Epoch 77/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3695 - accuracy: 0.8317
# Epoch 78/100
# 3983/3983 [==============================] - 6s 2ms/step - loss: 0.3695 - accuracy: 0.8316
# Epoch 79/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3694 - accuracy: 0.8319
# Epoch 80/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3693 - accuracy: 0.8319
# Epoch 81/100
# 3983/3983 [==============================] - 4s 980us/step - loss: 0.3694 - accuracy: 0.8315
# Epoch 82/100
# 3983/3983 [==============================] - 4s 972us/step - loss: 0.3693 - accuracy: 0.8318
# Epoch 83/100
# 3983/3983 [==============================] - 4s 986us/step - loss: 0.3693 - accuracy: 0.8320
# Epoch 84/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3691 - accuracy: 0.8319
# Epoch 85/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3693 - accuracy: 0.8313
# Epoch 86/100
# 3983/3983 [==============================] - 4s 992us/step - loss: 0.3691 - accuracy: 0.8321
# Epoch 87/100
# 3983/3983 [==============================] - 4s 970us/step - loss: 0.3693 - accuracy: 0.8315
# Epoch 88/100
# 3983/3983 [==============================] - 4s 990us/step - loss: 0.3690 - accuracy: 0.8314
# Epoch 89/100
# 3983/3983 [==============================] - 4s 997us/step - loss: 0.3690 - accuracy: 0.8320
# Epoch 90/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3690 - accuracy: 0.8322
# Epoch 91/100
# 3983/3983 [==============================] - 4s 971us/step - loss: 0.3690 - accuracy: 0.8319
# Epoch 92/100
# 3983/3983 [==============================] - 4s 985us/step - loss: 0.3691 - accuracy: 0.8316
# Epoch 93/100
# 3983/3983 [==============================] - 4s 994us/step - loss: 0.3688 - accuracy: 0.8321
# Epoch 94/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3689 - accuracy: 0.8316
# Epoch 95/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3689 - accuracy: 0.8317
# Epoch 96/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3688 - accuracy: 0.8323
# Epoch 97/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3688 - accuracy: 0.8321
# Epoch 98/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3689 - accuracy: 0.8324
# Epoch 99/100
# 3983/3983 [==============================] - 5s 1ms/step - loss: 0.3689 - accuracy: 0.8321
# Epoch 100/100
# 3983/3983 [==============================] - 4s 1ms/step - loss: 0.3688 - accuracy: 0.8316

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1328/1328 - 1s - loss: 0.3760 - accuracy: 0.8294 - 874ms/epoch - 658us/step
# Loss: 0.37599673867225647, Accuracy: 0.8293940424919128

# %%
X_top = top10_df[['acousticness','danceability','duration','energy','liveness','loudness','speechiness','tempo(BPM)','valence']]
X_top
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence
# 0           0.04          97     0.80
# 1           0.23          87     0.64
# 2           0.14         120     0.71
# 3           0.04         119     0.71
# 4           0.04         109     0.43
# ..           ...         ...      ...
# 598         0.03         104     0.16
# 599         0.12          95     0.61
# 600         0.34         136     0.65
# 601         0.07         114     0.24
# 602         0.06         150     0.23
#
# [603 rows x 9 columns]

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_top)

# Scale the data
X_top_scaled = X_scaler.transform(X_top)

# %% [markdown]
# ### Predictions

# %%
from tensorflow.keras.models import Sequential, save_model, load_model

# %%
# Save the model
filepath = './saved_model'
save_model(nn, filepath)
# Out:
# INFO:tensorflow:Assets written to: ./saved_model\assets

# %%
# Load the model
model = load_model(filepath, compile = True)

# %%
# Generate predictions for samples
predictions = model.predict(X_top_scaled)
print(predictions)
# Out:
# [[0.07545018]
#  [0.29156518]
#  [0.45232064]
#  [0.08762598]
#  [0.18078238]
#  [0.3531481 ]
#  [0.15417346]
#  [0.18597513]
#  [0.00213048]
#  [0.33456406]
#  [0.25892755]
#  [0.16412818]
#  [0.12454617]
#  [0.2546327 ]
#  [0.00219375]
#  [0.07616061]
#  [0.16253367]
#  [0.155296  ]
#  [0.07178062]
#  [0.30827308]
#  [0.1399191 ]
#  [0.24085805]
#  [0.19711602]
#  [0.11702061]
#  [0.08418718]
#  [0.03131887]
#  [0.06374756]
#  [0.19677061]
#  [0.22126883]
#  [0.43353266]
#  [0.4001084 ]
#  [0.04655644]
#  [0.18141744]
#  [0.0353581 ]
#  [0.07265669]
#  [0.08893681]
#  [0.00245789]
#  [0.05283263]
#  [0.04707381]
#  [0.25359654]
#  [0.00448474]
#  [0.24710587]
#  [0.64057267]
#  [0.04390234]
#  [0.00213006]
#  [0.12189451]
#  [0.1592516 ]
#  [0.62712294]
#  [0.06989032]
#  [0.03587317]
#  [0.13824868]
#  [0.12390316]
#  [0.00255799]
#  [0.08136177]
#  [0.18078238]
#  [0.26912132]
#  [0.2726385 ]
#  [0.08267963]
#  [0.17603093]
#  [0.05399105]
#  [0.15603974]
#  [0.19773951]
#  [0.60257286]
#  [0.09044915]
#  [0.00225124]
#  [0.06813717]
#  [0.1647428 ]
#  [0.13141781]
#  [0.51736754]
#  [0.11036974]
#  [0.11772683]
#  [0.0804731 ]
#  [0.09277603]
#  [0.18042862]
#  [0.00213578]
#  [0.20963389]
#  [0.61095667]
#  [0.12686405]
#  [0.0449141 ]
#  [0.17195451]
#  [0.15086624]
#  [0.0912008 ]
#  [0.15776548]
#  [0.06781393]
#  [0.04927334]
#  [0.37032247]
#  [0.19018784]
#  [0.4788864 ]
#  [0.14371735]
#  [0.7543305 ]
#  [0.55506146]
#  [0.17714995]
#  [0.10988882]
#  [0.05860353]
#  [0.05149642]
#  [0.00213003]
#  [0.0032402 ]
#  [0.5435659 ]
#  [0.07156166]
#  [0.2830956 ]
#  [0.10002711]
#  [0.9086244 ]
#  [0.18093735]
#  [0.2144798 ]
#  [0.13426417]
#  [0.0726676 ]
#  [0.24100137]
#  [0.04104507]
#  [0.00213003]
#  [0.00213909]
#  [0.00213024]
#  [0.09797284]
#  [0.25719798]
#  [0.14330077]
#  [0.00293633]
#  [0.2650607 ]
#  [0.8654724 ]
#  [0.05645725]
#  [0.27099293]
#  [0.08170262]
#  [0.07231131]
#  [0.04086366]
#  [0.17163524]
#  [0.24809003]
#  [0.3617124 ]
#  [0.28239223]
#  [0.08130276]
#  [0.01439255]
#  [0.00539833]
#  [0.07808864]
#  [0.7056331 ]
#  [0.02285066]
#  [0.6897732 ]
#  [0.1195327 ]
#  [0.07051709]
#  [0.12682325]
#  [0.5014271 ]
#  [0.07504681]
#  [0.1867285 ]]

# %%
top10_df["popularity_predict"] = predictions
top10_df
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year  popularity_predict
# 0           0.04          97     0.80  2010            0.075450
# 1           0.23          87     0.64  2010            0.291565
# 2           0.14         120     0.71  2010            0.452321
# 3           0.04         119     0.71  2010            0.087626
# 4           0.04         109     0.43  2010            0.180782
# ..           ...         ...      ...   ...                 ...
# 598         0.03         104     0.16  2019            0.070517
# 599         0.12          95     0.61  2019            0.126823
# 600         0.34         136     0.65  2019            0.501427
# 601         0.07         114     0.24  2019            0.075047
# 602         0.06         150     0.23  2019            0.186729
#
# [603 rows x 11 columns]

# %% [markdown]
# ### Plotting

# %%
# for i in top10_df['popularity_predict']:
#     if i >= .05:
#         top10df['popular'] = 1
#     elif i < .05:
#         top10df['popular'] = 0
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year  popularity  popularity_predict
# 0           0.04          97     0.80  2010          83            0.000540
# 1           0.23          87     0.64  2010          82            0.000540
# 2           0.14         120     0.71  2010          80            0.000540
# 3           0.04         119     0.71  2010          79            0.000540
# 4           0.04         109     0.43  2010          78            0.000540
# ..           ...         ...      ...   ...         ...                 ...
# 598         0.03         104     0.16  2019          75            0.996379
# 599         0.12          95     0.61  2019          75            0.977933
# 600         0.34         136     0.65  2019          70            0.995155
# 601         0.07         114     0.24  2019          69            0.968222
# 602         0.06         150     0.23  2019          67            0.992640
#
# [603 rows x 12 columns]

# %%
y_axis = top10_df['popularity_predict']
x_axis = top10_df['danceability']

plt.scatter(x_axis, y_axis)
plt.plot([0, 1], [0.5, 0.5], 'k-', lw=2)
plt.xlabel("Danceability")
plt.ylabel("Popularity")
plt.show()

# %%
y_axis = top10_df['popularity_predict']
x_axis = top10_df['year']

plt.scatter(x_axis, y_axis)
plt.plot([2010, 2019], [0.5, 0.5], 'k-', lw=2)
plt.xlabel("Year")
plt.ylabel("Popularity")
plt.show()

# %%
y_axis = top10_df['popularity_predict']
x_axis = top10_df['energy']

plt.scatter(x_axis, y_axis)
plt.plot([0, 1], [0.5, 0.5], 'k-', lw=2)
plt.xlabel("Energy")
plt.ylabel("Popularity")
plt.show()

# %%
y_axis = top10_df['popularity_predict']
x_axis = top10_df['tempo(BPM)']

plt.scatter(x_axis, y_axis)
plt.plot([0, 200], [0.5, 0.5], 'k-', lw=2)
plt.xlabel("Tempo (BPM)")
plt.ylabel("Popularity")
plt.show()

# %%
y_axis = top10_df['popularity_predict']
x_axis = top10_df['speechiness']

plt.scatter(x_axis, y_axis)
plt.plot([0, 1], [0.5, 0.5], 'k-', lw=2)
plt.xlabel("Speechiness")
plt.ylabel("Popularity")
plt.show()

# %%
y_axis = top10_df['popularity_predict']
x_axis = top10_df['liveness']

plt.scatter(x_axis, y_axis)
plt.plot([0, 1], [0.5, 0.5], 'k-', lw=2)
plt.xlabel("Liveness")
plt.ylabel("Popularity")
plt.show()

# %%
y_axis = top10_df['popularity_predict']
x_axis = top10_df['duration']

plt.scatter(x_axis, y_axis)
plt.plot([100000, 450000], [0.5, 0.5], 'k-', lw=2)
plt.xlabel("Duration")
plt.ylabel("Popularity")
plt.show()

# %%
column = top10_df['popularity_predict']
max_value = column.max()
max_value
# Out:
# 0.9086244106292725

# %%
column = top10_df['popularity_predict']
max_index = column.idxmax()
print(top10_df.loc[[max_index]])
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 565          0.16          0.63    227000    0.69      0.12        -4
#
#      speechiness  tempo(BPM)  valence  year  popularity_predict
# 565         0.09         130     0.25  2018            0.908624
