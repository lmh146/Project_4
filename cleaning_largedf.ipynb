# %%
# Initial imports
import pandas as pd
from pathlib import Path

# %%
# Data loading
file_path = Path("Resources/1921_2020.csv")
df = pd.read_csv(file_path)
df.sort_values(by='popularity', ascending=False)
# Out:
#         acousticness                                     artists  \
# 87942        0.00146                              ['The Weeknd']
# 87940        0.24700                   ['DaBaby', 'Roddy Ricch']
# 87949        0.73100                    ['Powfu', 'beabadoobee']
# 87941        0.23300  ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']
# 87852        0.06860                     ['Surf Mesa', 'Emilee']
# ...              ...                                         ...
# 145185       0.99500             ['Leela Chitnis', 'Arun Kumar']
# 145183       0.80400                                    ['Ravi']
# 145181       0.99500   ['Ibrahim Özgür', 'Park Otel Orkestrası']
# 145179       0.99200   ['Ludwig van Beethoven', 'Claudio Arrau']
# 0            0.99500                         ['Carl Woitschach']
#
#         danceability  duration_ms   energy  explicit                      id  \
# 87942          0.514       200040  0.73000         0  0VjIjW4GlUZAMYd2vXMi3b
# ...

# %%
dropped_df = df.drop(columns=['artists', 'id', 'name', 'release_date', 'explicit', 'mode', 'key'])
dropped_df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0         0.995         0.708       158648  0.1950             0.563
# 1         0.994         0.379       282133  0.0135             0.901
# 2         0.604         0.749       104300  0.2200             0.000
# 3         0.995         0.781       180760  0.1300             0.887
# 4         0.990         0.210       687733  0.2040             0.908
#
#    liveness  loudness  popularity  speechiness    tempo  valence  year
# 0    0.1510   -12.428           0       0.0506  118.469   0.7790  1928
# 1    0.0763   -28.454           0       0.0462   83.972   0.0767  1928
# 2    0.1190   -19.924           0       0.9290  107.177   0.8800  1928
# 3    0.1110   -14.734           0       0.0926  108.003   0.7200  1928
# 4    0.0980   -16.829           1       0.0424   62.149   0.0693  1928

# %%
# rename_df = dropped_df.rename(columns = {"bpm" : "tempo(BPM)",
#                                          "nrgy" : "energy",
#                                          "dnce" : "danceability",
#                                          "dB" : "loudness",
#                                          "live" : "liveness",
#                                          "val" : "valence",
#                                          "dur" : "duration",
#                                          "acous" : "acousticness",
#                                          "spch" : "speechiness",
#                                          "pop" : "popularity"
#                                         })

# %%
bigdf_clean = dropped_df.rename(columns = {"duration_ms" : "duration",
                                         "tempo" : "tempo(BPM)"
                                        })

# %%
bigdf_clean
# Out:
#         acousticness  danceability  duration  energy  instrumentalness  \
# 0             0.9950         0.708    158648  0.1950          0.563000
# 1             0.9940         0.379    282133  0.0135          0.901000
# 2             0.6040         0.749    104300  0.2200          0.000000
# 3             0.9950         0.781    180760  0.1300          0.887000
# 4             0.9900         0.210    687733  0.2040          0.908000
# ...              ...           ...       ...     ...               ...
# 169904        0.1730         0.875    163800  0.4430          0.000032
# 169905        0.0167         0.719    167468  0.3850          0.031300
# 169906        0.5380         0.514    180700  0.5390          0.002330
# 169907        0.0714         0.646    167308  0.7610          0.000000
# 169908        0.1090         0.512    214787  0.4280          0.000000
#
#         liveness  loudness  popularity  speechiness  tempo(BPM)  valence  year
# ...

# %%
bigdf_clean.to_csv('Resources/bigdf_clean.csv')
