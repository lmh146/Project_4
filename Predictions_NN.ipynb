# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

#  Import and read the charity_data.csv.
import pandas as pd 
top10_df = pd.read_csv("Resources/cleaned_top10.csv")
big_df = pd.read_csv("Resources/bigdf_binary.csv")

# %%
top10_df
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year  popularity
# 0           0.04          97     0.80  2010          83
# 1           0.23          87     0.64  2010          82
# 2           0.14         120     0.71  2010          80
# 3           0.04         119     0.71  2010          79
# 4           0.04         109     0.43  2010          78
# ..           ...         ...      ...   ...         ...
# 598         0.03         104     0.16  2019          75
# 599         0.12          95     0.61  2019          75
# 600         0.34         136     0.65  2019          70
# 601         0.07         114     0.24  2019          69
# 602         0.06         150     0.23  2019          67
#
# [603 rows x 11 columns]

# %%
big_df
# Out:
#         Unnamed: 0  Unnamed: 0.1  acousticness  danceability  duration  \
# 0                0             0        0.9950         0.708    158648
# 1                1             1        0.9940         0.379    282133
# 2                2             2        0.6040         0.749    104300
# 3                3             3        0.9950         0.781    180760
# 4                4             4        0.9900         0.210    687733
# ...            ...           ...           ...           ...       ...
# 169904      169904        169904        0.1730         0.875    163800
# 169905      169905        169905        0.0167         0.719    167468
# 169906      169906        169906        0.5380         0.514    180700
# 169907      169907        169907        0.0714         0.646    167308
# 169908      169908        169908        0.1090         0.512    214787
#
#         energy  instrumentalness  liveness  loudness  popularity  speechiness  \
# 0       0.1950          0.563000    0.1510   -12.428           0       0.0506
# 1       0.0135          0.901000    0.0763   -28.454           0       0.0462
# 2       0.2200          0.000000    0.1190   -19.924           0       0.9290
# 3       0.1300          0.887000    0.1110   -14.734           0       0.0926
# 4       0.2040          0.908000    0.0980   -16.829           0       0.0424
# ...        ...               ...       ...       ...         ...          ...
# 169904  0.4430          0.000032    0.0891    -7.461           1       0.1430
# 169905  0.3850          0.031300    0.1110   -10.907           1       0.0403
# 169906  0.5390          0.002330    0.1080    -9.332           1       0.1050
# 169907  0.7610          0.000000    0.2220    -2.557           1       0.0385
# 169908  0.4280          0.000000    0.1050    -7.387           1       0.0271
#
#         tempo(BPM)  valence  year
# 0          118.469   0.7790  1928
# 1           83.972   0.0767  1928
# 2          107.177   0.8800  1928
# 3          108.003   0.7200  1928
# 4           62.149   0.0693  1928
# ...            ...      ...   ...
# 169904     100.012   0.3060  2020
# 169905     128.000   0.2700  2020
# 169906     123.700   0.1530  2020
# 169907     129.916   0.4720  2020
# 169908      80.588   0.3660  2020
#
# [169909 rows x 14 columns]

# %%
# Drop from Big df
big_df = big_df.drop(columns = ['Unnamed: 0','Unnamed: 0.1','instrumentalness'])
big_df
# Out:
#         acousticness  danceability  duration  energy  liveness  loudness  \
# 0             0.9950         0.708    158648  0.1950    0.1510   -12.428
# 1             0.9940         0.379    282133  0.0135    0.0763   -28.454
# 2             0.6040         0.749    104300  0.2200    0.1190   -19.924
# 3             0.9950         0.781    180760  0.1300    0.1110   -14.734
# 4             0.9900         0.210    687733  0.2040    0.0980   -16.829
# ...              ...           ...       ...     ...       ...       ...
# 169904        0.1730         0.875    163800  0.4430    0.0891    -7.461
# 169905        0.0167         0.719    167468  0.3850    0.1110   -10.907
# 169906        0.5380         0.514    180700  0.5390    0.1080    -9.332
# 169907        0.0714         0.646    167308  0.7610    0.2220    -2.557
# 169908        0.1090         0.512    214787  0.4280    0.1050    -7.387
#
#         popularity  speechiness  tempo(BPM)  valence
# 0                0       0.0506     118.469   0.7790
# 1                0       0.0462      83.972   0.0767
# 2                0       0.9290     107.177   0.8800
# 3                0       0.0926     108.003   0.7200
# 4                0       0.0424      62.149   0.0693
# ...            ...          ...         ...      ...
# 169904           1       0.1430     100.012   0.3060
# 169905           1       0.0403     128.000   0.2700
# 169906           1       0.1050     123.700   0.1530
# 169907           1       0.0385     129.916   0.4720
# 169908           1       0.0271      80.588   0.3660
#
# [169909 rows x 10 columns]

# %%
# Drop Popularity
top10_df = top10_df.drop(columns = 'popularity')
top10_df
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year
# 0           0.04          97     0.80  2010
# 1           0.23          87     0.64  2010
# 2           0.14         120     0.71  2010
# 3           0.04         119     0.71  2010
# 4           0.04         109     0.43  2010
# ..           ...         ...      ...   ...
# 598         0.03         104     0.16  2019
# 599         0.12          95     0.61  2019
# 600         0.34         136     0.65  2019
# 601         0.07         114     0.24  2019
# 602         0.06         150     0.23  2019
#
# [603 rows x 10 columns]

# %%
# # Vectorize the dataset
# X = dataset.iloc[:, :-1].values #pulls everything up to but not including last column
# y = dataset.iloc[:, -1].values #pulls all data from last column

# %%
# Split our preprocessed data into our features and target arrays
y = big_df['popularity']
X = big_df.drop(['popularity'], axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim= number_input_features, name = 'layer1')) 

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=18, activation="relu", name = 'layer2'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation="tanh", name = 'layer3'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid")) 

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 20)                200
#
#  layer2 (Dense)              (None, 18)                378
#
#  layer3 (Dense)              (None, 10)                190
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 779
# Trainable params: 779
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Create a callback that saves the model's weights every 5 epochs
callback = tf.keras.callbacks.ModelCheckpoint(filepath = "Models/weights.{epoch:05d}.hdf5", save_freg = "epoch", period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3970 - accuracy: 0.8194
# Epoch 2/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3865 - accuracy: 0.8249
# Epoch 3/100
# 3983/3983 [==============================] - 15s 4ms/step - loss: 0.3835 - accuracy: 0.8260
# Epoch 4/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3819 - accuracy: 0.8274
# Epoch 5/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3804 - accuracy: 0.8273
# Epoch 6/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3794 - accuracy: 0.8281
# Epoch 7/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3789 - accuracy: 0.8278
# Epoch 8/100
# 3983/3983 [==============================] - 10s 3ms/step - loss: 0.3778 - accuracy: 0.8283
# Epoch 9/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3778 - accuracy: 0.8284
# Epoch 10/100
# 3983/3983 [==============================] - 15s 4ms/step - loss: 0.3774 - accuracy: 0.8294
# Epoch 11/100
# 3983/3983 [==============================] - 11s 3ms/step - loss: 0.3768 - accuracy: 0.8288
# Epoch 12/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3766 - accuracy: 0.8286
# Epoch 13/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3762 - accuracy: 0.8289
# Epoch 14/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3760 - accuracy: 0.8287
# Epoch 15/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3759 - accuracy: 0.8288
# Epoch 16/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3755 - accuracy: 0.8289
# Epoch 17/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3752 - accuracy: 0.8294
# Epoch 18/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3751 - accuracy: 0.8296
# Epoch 19/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3750 - accuracy: 0.8293
# Epoch 20/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3746 - accuracy: 0.8295
# Epoch 21/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3745 - accuracy: 0.8293
# Epoch 22/100
# 3983/3983 [==============================] - 16s 4ms/step - loss: 0.3744 - accuracy: 0.8299
# Epoch 23/100
# 3983/3983 [==============================] - 15s 4ms/step - loss: 0.3744 - accuracy: 0.8292
# Epoch 24/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3741 - accuracy: 0.8292
# Epoch 25/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3740 - accuracy: 0.8302
# Epoch 26/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3740 - accuracy: 0.8295
# Epoch 27/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3738 - accuracy: 0.8297
# Epoch 28/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3736 - accuracy: 0.8307
# Epoch 29/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3734 - accuracy: 0.8301
# Epoch 30/100
# 3983/3983 [==============================] - 15s 4ms/step - loss: 0.3734 - accuracy: 0.8297
# Epoch 31/100
# 3983/3983 [==============================] - 11s 3ms/step - loss: 0.3734 - accuracy: 0.8302
# Epoch 32/100
# 3983/3983 [==============================] - 16s 4ms/step - loss: 0.3731 - accuracy: 0.8302
# Epoch 33/100
# 3983/3983 [==============================] - 16s 4ms/step - loss: 0.3731 - accuracy: 0.8308
# Epoch 34/100
# 3983/3983 [==============================] - 14s 4ms/step - loss: 0.3731 - accuracy: 0.8306
# Epoch 35/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3731 - accuracy: 0.8306
# Epoch 36/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3728 - accuracy: 0.8306
# Epoch 37/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3729 - accuracy: 0.8305
# Epoch 38/100
# 3983/3983 [==============================] - 14s 4ms/step - loss: 0.3727 - accuracy: 0.8300
# Epoch 39/100
# 3983/3983 [==============================] - 15s 4ms/step - loss: 0.3724 - accuracy: 0.8302
# Epoch 40/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3727 - accuracy: 0.8306
# Epoch 41/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3724 - accuracy: 0.8311
# Epoch 42/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3723 - accuracy: 0.8309
# Epoch 43/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3724 - accuracy: 0.8307
# Epoch 44/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3722 - accuracy: 0.8304
# Epoch 45/100
# 3983/3983 [==============================] - 14s 4ms/step - loss: 0.3721 - accuracy: 0.8314
# Epoch 46/100
# 3983/3983 [==============================] - 15s 4ms/step - loss: 0.3720 - accuracy: 0.8312
# Epoch 47/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3718 - accuracy: 0.8312
# Epoch 48/100
# 3983/3983 [==============================] - 14s 4ms/step - loss: 0.3719 - accuracy: 0.8314
# Epoch 49/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3716 - accuracy: 0.8310
# Epoch 50/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3717 - accuracy: 0.8310
# Epoch 51/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3716 - accuracy: 0.8312
# Epoch 52/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3715 - accuracy: 0.8312
# Epoch 53/100
# 3983/3983 [==============================] - 14s 4ms/step - loss: 0.3715 - accuracy: 0.8314
# Epoch 54/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3716 - accuracy: 0.8313
# Epoch 55/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3713 - accuracy: 0.8315
# Epoch 56/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3712 - accuracy: 0.8310
# Epoch 57/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3712 - accuracy: 0.8313
# Epoch 58/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3712 - accuracy: 0.8315
# Epoch 59/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3709 - accuracy: 0.8317
# Epoch 60/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3711 - accuracy: 0.8310
# Epoch 61/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3712 - accuracy: 0.8316
# Epoch 62/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3709 - accuracy: 0.8317
# Epoch 63/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3709 - accuracy: 0.8314
# Epoch 64/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3708 - accuracy: 0.8318
# Epoch 65/100
# 3983/3983 [==============================] - 11s 3ms/step - loss: 0.3708 - accuracy: 0.8313
# Epoch 66/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3708 - accuracy: 0.8317
# Epoch 67/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3705 - accuracy: 0.8318
# Epoch 68/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3707 - accuracy: 0.8319
# Epoch 69/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3708 - accuracy: 0.8318
# Epoch 70/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3706 - accuracy: 0.8317
# Epoch 71/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3703 - accuracy: 0.8317
# Epoch 72/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3703 - accuracy: 0.8320
# Epoch 73/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3704 - accuracy: 0.8317
# Epoch 74/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3705 - accuracy: 0.8320
# Epoch 75/100
# 3983/3983 [==============================] - 11s 3ms/step - loss: 0.3704 - accuracy: 0.8321
# Epoch 76/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3701 - accuracy: 0.8322
# Epoch 77/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3702 - accuracy: 0.8320
# Epoch 78/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3703 - accuracy: 0.8322
# Epoch 79/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3703 - accuracy: 0.8318
# Epoch 80/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3701 - accuracy: 0.8326
# Epoch 81/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3700 - accuracy: 0.8326
# Epoch 82/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3699 - accuracy: 0.8319
# Epoch 83/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3701 - accuracy: 0.8321
# Epoch 84/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3700 - accuracy: 0.8318
# Epoch 85/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3698 - accuracy: 0.8317
# Epoch 86/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3699 - accuracy: 0.8323
# Epoch 87/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3699 - accuracy: 0.8317
# Epoch 88/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3699 - accuracy: 0.8320
# Epoch 89/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3698 - accuracy: 0.8325
# Epoch 90/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3698 - accuracy: 0.8327
# Epoch 91/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3695 - accuracy: 0.8323
# Epoch 92/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3696 - accuracy: 0.8319
# Epoch 93/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3696 - accuracy: 0.8319
# Epoch 94/100
# 3983/3983 [==============================] - 13s 3ms/step - loss: 0.3696 - accuracy: 0.8320
# Epoch 95/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3696 - accuracy: 0.8323
# Epoch 96/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3696 - accuracy: 0.8326
# Epoch 97/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3696 - accuracy: 0.8321
# Epoch 98/100
# 3983/3983 [==============================] - 14s 3ms/step - loss: 0.3693 - accuracy: 0.8322
# Epoch 99/100
# 3983/3983 [==============================] - 11s 3ms/step - loss: 0.3693 - accuracy: 0.8325
# Epoch 100/100
# 3983/3983 [==============================] - 12s 3ms/step - loss: 0.3697 - accuracy: 0.8324

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1328/1328 - 4s - loss: 0.3765 - accuracy: 0.8310 - 4s/epoch - 3ms/step
# Loss: 0.37651798129081726, Accuracy: 0.8310183882713318

# %%
X_top = top10_df[['acousticness','danceability','duration','energy','liveness','loudness','speechiness','tempo(BPM)','valence','year']]
X_top
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence
# 0           0.04          97     0.80
# 1           0.23          87     0.64
# 2           0.14         120     0.71
# 3           0.04         119     0.71
# 4           0.04         109     0.43
# ..           ...         ...      ...
# 598         0.03         104     0.16
# 599         0.12          95     0.61
# 600         0.34         136     0.65
# 601         0.07         114     0.24
# 602         0.06         150     0.23
#
# [603 rows x 9 columns]

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_top)

# Scale the data
X_top_scaled = X_scaler.transform(X_top)

# %% [markdown]
# ### Predictions

# %%
from tensorflow.keras.models import Sequential, save_model, load_model

# %%
# Save the model
filepath = './saved_model'
save_model(nn, filepath)
# Out:
# INFO:tensorflow:Assets written to: ./saved_model\assets

# %%
# Load the model
model = load_model(filepath, compile = True)

# %%
# Generate predictions for samples
predictions = model.predict(X_top_scaled)
print(predictions)
# Out:
# [[0.15620622]
#  [0.27716136]
#  [0.34296027]
#  [0.2217221 ]
#  [0.13624978]
#  [0.36150706]
#  [0.13958094]
#  [0.14064708]
#  [0.00203553]
#  [0.40409005]
#  [0.20713618]
#  [0.18252334]
#  [0.36317512]
#  [0.33561718]
#  [0.00204885]
#  [0.31048915]
#  [0.11663121]
#  [0.06451228]
#  [0.07854733]
#  [0.25510252]
#  [0.18181273]
#  [0.20280734]
#  [0.18007556]
#  [0.18033677]
#  [0.07496122]
#  [0.08412439]
#  [0.09341529]
#  [0.17755932]
#  [0.24400717]
#  [0.5372158 ]
#  [0.4761295 ]
#  [0.0477933 ]
#  [0.17602614]
#  [0.01497033]
#  [0.08267513]
#  [0.08135164]
#  [0.00203702]
#  [0.12821293]
#  [0.01874727]
#  [0.20194629]
#  [0.00393245]
#  [0.30168456]
#  [0.15904918]
#  [0.05751586]
#  [0.00203541]
#  [0.07114869]
#  [0.17008096]
#  [0.5623113 ]
#  [0.26846808]
#  [0.07430422]
#  [0.1289539 ]
#  [0.22928381]
#  [0.00203544]
#  [0.2957163 ]
#  [0.13624978]
#  [0.21219793]
#  [0.1987465 ]
#  [0.20124248]
#  [0.08670369]
#  [0.23590094]
#  [0.09887013]
#  [0.1314084 ]
#  [0.08128449]
#  [0.03277364]
#  [0.18252334]
#  [0.40746847]
#  [0.6519762 ]
#  [0.11599657]
#  [0.5350253 ]
#  [0.12278455]
#  [0.2484152 ]
#  [0.15848023]
#  [0.2184929 ]
#  [0.4107745 ]
#  [0.25411814]
#  [0.08248007]
#  [0.17891955]
#  [0.24731645]
#  [0.18888909]
#  [0.14186722]
#  [0.26771116]
#  [0.03942955]
#  [0.14248726]
#  [0.34316128]
#  [0.12109983]
#  [0.26993737]
#  [0.135993  ]
#  [0.19748658]
#  [0.20560864]
#  [0.21240133]
#  [0.09602314]
#  [0.24279624]
#  [0.27572626]
#  [0.17008096]
#  [0.00204486]
#  [0.26846802]
#  [0.00203538]
#  [0.0299128 ]
#  [0.0665108 ]
#  [0.2094993 ]
#  [0.00264734]
#  [0.18421617]
#  [0.12749684]
#  [0.0023599 ]
#  [0.68537325]
#  [0.31860918]
#  [0.16663554]
#  [0.25488514]
#  [0.2192947 ]
#  [0.18427008]
#  [0.0664064 ]
#  [0.0931825 ]
#  [0.30513823]
#  [0.06395513]
#  [0.10798296]
#  [0.24554536]
#  [0.62059724]
#  [0.3079986 ]
#  [0.04964545]
#  [0.27029547]
#  [0.11954057]
#  [0.30583227]
#  [0.12198526]
#  [0.12372378]
#  [0.17258763]
#  [0.2268902 ]
#  [0.12140542]
#  [0.16322955]
#  [0.2764284 ]
#  [0.2117025 ]
#  [0.07639235]
#  [0.1292381 ]
#  [0.05214235]
#  [0.20131472]
#  [0.03817263]
#  [0.00209662]
#  [0.21302041]
#  [0.08700526]
#  [0.17648795]
#  [0.11567184]
#  [0.09351128]
#  [0.16007084]
#  [0.1985175 ]
#  [0.08380395]
#  [0.2733124 ]
#  [0.19263938]
#  [0.29214934]
#  [0.19144633]
#  [0.15510857]
#  [0.40785933]
#  [0.24332908]
#  [0.20008573]
#  [0.06395513]
#  [0.13194856]
#  [0.4348762 ]
#  [0.17993405]
#  [0.06598261]
#  [0.03665817]
#  [0.36278298]
#  [0.22350737]
#  [0.07439467]
#  [0.03825578]
#  [0.0698407 ]
#  [0.06602508]
#  [0.28777972]
#  [0.12958825]
#  [0.5890901 ]
#  [0.24115694]
#  [0.1996142 ]
#  [0.1389184 ]
#  [0.13920096]
#  [0.10619098]
#  [0.47178823]
#  [0.23464918]
#  [0.06575078]
#  [0.41333213]
#  [0.17465913]
#  [0.16534305]
#  [0.35512668]
#  [0.22560927]
#  [0.33859545]
#  [0.04260176]
#  [0.0604341 ]
#  [0.08273453]
#  [0.0866951 ]
#  [0.07447395]
#  [0.00203538]
#  [0.42547268]
#  [0.00541586]
#  [0.36811936]
#  [0.4197219 ]
#  [0.11315131]
#  [0.00218666]
#  [0.1075131 ]
#  [0.02337551]
#  [0.23921824]
#  [0.06396377]
#  [0.0988254 ]
#  [0.08099756]
#  [0.05913827]
#  [0.00276789]
#  [0.34330577]
#  [0.17375773]
#  [0.12477094]
#  [0.280711  ]
#  [0.05689001]
#  [0.24047884]
#  [0.16063055]
#  [0.1343202 ]
#  [0.18401235]
#  [0.00203538]
#  [0.00213885]
#  [0.16600904]
#  [0.09217304]
#  [0.24507096]
#  [0.09816453]
#  [0.17761844]
#  [0.13906097]
#  [0.06390396]
#  [0.06476578]
#  [0.1261799 ]
#  [0.14771292]
#  [0.14606848]
#  [0.15230167]
#  [0.13699076]
#  [0.2054672 ]
#  [0.3352039 ]
#  [0.23084915]
#  [0.21419016]
#  [0.03647214]
#  [0.9278879 ]
#  [0.03281888]
#  [0.07009071]
#  [0.26307866]
#  [0.00904331]
#  [0.12277803]
#  [0.13589922]
#  [0.08566698]
#  [0.20381668]
#  [0.35512668]
#  [0.49373943]
#  [0.02647483]
#  [0.0803366 ]
#  [0.21922234]
#  [0.28358674]
#  [0.15305498]
#  [0.22829455]
#  [0.13359424]
#  [0.26327574]
#  [0.00203562]
#  [0.2390041 ]
#  [0.06841508]
#  [0.1383692 ]
#  [0.00315648]
#  [0.13900751]
#  [0.00203538]
#  [0.07213631]
#  [0.35485542]
#  [0.17006421]
#  [0.17438772]
#  [0.00217235]
#  [0.22490379]
#  [0.0791156 ]
#  [0.29908925]
#  [0.27584368]
#  [0.04775193]
#  [0.00296593]
#  [0.05646697]
#  [0.0097059 ]
#  [0.01318255]
#  [0.16976237]
#  [0.00203538]
#  [0.11726376]
#  [0.00205585]
#  [0.28195113]
#  [0.13814583]
#  [0.00203544]
#  [0.11232114]
#  [0.22343397]
#  [0.00203586]
#  [0.0991717 ]
#  [0.09571722]
#  [0.05993417]
#  [0.08203691]
#  [0.00203544]
#  [0.65735567]
#  [0.13118282]
#  [0.2507979 ]
#  [0.03037235]
#  [0.1239273 ]
#  [0.62076694]
#  [0.30465865]
#  [0.06179532]
#  [0.09429032]
#  [0.23631898]
#  [0.16167995]
#  [0.03007317]
#  [0.58735603]
#  [0.20673573]
#  [0.42494527]
#  [0.03272408]
#  [0.14108959]
#  [0.23265895]
#  [0.7297621 ]
#  [0.07575345]
#  [0.10497054]
#  [0.11843595]
#  [0.10489097]
#  [0.18475917]
#  [0.00210556]
#  [0.4087454 ]
#  [0.30677438]
#  [0.4300505 ]
#  [0.06382534]
#  [0.73179805]
#  [0.05083734]
#  [0.12903735]
#  [0.13703302]
#  [0.13199636]
#  [0.1118075 ]
#  [0.10540092]
#  [0.04097903]
#  [0.28195113]
#  [0.00296   ]
#  [0.07724571]
#  [0.09939292]
#  [0.07098562]
#  [0.11718953]
#  [0.285923  ]
#  [0.00203544]
#  [0.0020355 ]
#  [0.16072914]
#  [0.01515648]
#  [0.10953924]
#  [0.0620302 ]
#  [0.09327441]
#  [0.09904692]
#  [0.04851505]
#  [0.0708445 ]
#  [0.18897587]
#  [0.31986892]
#  [0.20967343]
#  [0.27801558]
#  [0.3214256 ]
#  [0.08995509]
#  [0.08172089]
#  [0.55116343]
#  [0.15570205]
#  [0.15764269]
#  [0.17736992]
#  [0.08658129]
#  [0.06402647]
#  [0.00203654]
#  [0.2312575 ]
#  [0.09962541]
#  [0.06930944]
#  [0.06823424]
#  [0.16932416]
#  [0.6964575 ]
#  [0.01707143]
#  [0.18198615]
#  [0.28554368]
#  [0.13785928]
#  [0.16976237]
#  [0.00203538]
#  [0.13856411]
#  [0.12718484]
#  [0.06189144]
#  [0.17334616]
#  [0.16873503]
#  [0.03076264]
#  [0.2869338 ]
#  [0.32468003]
#  [0.09738058]
#  [0.15171704]
#  [0.12580442]
#  [0.07332203]
#  [0.11700919]
#  [0.0991717 ]
#  [0.15518653]
#  [0.06366429]
#  [0.32152086]
#  [0.11507311]
#  [0.30343336]
#  [0.09059963]
#  [0.28436765]
#  [0.09988743]
#  [0.0964359 ]
#  [0.05894747]
#  [0.15673468]
#  [0.08767357]
#  [0.11106628]
#  [0.28256935]
#  [0.09107152]
#  [0.0609774 ]
#  [0.20480198]
#  [0.14108959]
#  [0.14448482]
#  [0.00203565]
#  [0.19478899]
#  [0.2361506 ]
#  [0.20808476]
#  [0.4246399 ]
#  [0.4087454 ]
#  [0.05083734]
#  [0.05533227]
#  [0.20064613]
#  [0.10854098]
#  [0.07503754]
#  [0.05158663]
#  [0.08478707]
#  [0.00240675]
#  [0.02557191]
#  [0.3737148 ]
#  [0.10867205]
#  [0.1717636 ]
#  [0.26719797]
#  [0.11968672]
#  [0.9358092 ]
#  [0.06365138]
#  [0.02069956]
#  [0.15307942]
#  [0.00203562]
#  [0.18429765]
#  [0.00203544]
#  [0.07575083]
#  [0.09381583]
#  [0.03167325]
#  [0.15573147]
#  [0.1360912 ]
#  [0.09747937]
#  [0.00203538]
#  [0.54378176]
#  [0.08476195]
#  [0.25467375]
#  [0.07470393]
#  [0.00203538]
#  [0.07354662]
#  [0.2750099 ]
#  [0.14949512]
#  [0.67422247]
#  [0.11750811]
#  [0.7282653 ]
#  [0.00203583]
#  [0.09875378]
#  [0.40411437]
#  [0.02064747]
#  [0.13831279]
#  [0.15964806]
#  [0.06798655]
#  [0.49935246]
#  [0.3331228 ]
#  [0.13052452]
#  [0.07735145]
#  [0.10810229]
#  [0.20046079]
#  [0.00984964]
#  [0.30258635]
#  [0.5550963 ]
#  [0.19223419]
#  [0.036542  ]
#  [0.16560858]
#  [0.18147904]
#  [0.3772741 ]
#  [0.13963169]
#  [0.01115885]
#  [0.09968576]
#  [0.00249895]
#  [0.33034343]
#  [0.33762312]
#  [0.2104663 ]
#  [0.01252905]
#  [0.04062998]
#  [0.00203565]
#  [0.05375853]
#  [0.15493539]
#  [0.00222322]
#  [0.37633663]
#  [0.00228283]
#  [0.20311978]
#  [0.2172175 ]
#  [0.5496383 ]
#  [0.21698779]
#  [0.32378268]
#  [0.05326459]
#  [0.24929199]
#  [0.15629634]
#  [0.19765323]
#  [0.09123582]
#  [0.06182486]
#  [0.11699924]
#  [0.2395516 ]
#  [0.06504393]
#  [0.18090647]
#  [0.2381866 ]
#  [0.00217801]
#  [0.06324384]
#  [0.25200716]
#  [0.15525532]
#  [0.00205052]
#  [0.05465084]
#  [0.11091787]
#  [0.1260511 ]
#  [0.1588225 ]
#  [0.10211575]
#  [0.00203544]
#  [0.08463004]
#  [0.18748292]
#  [0.7396532 ]
#  [0.66598547]
#  [0.33473182]
#  [0.09486872]
#  [0.03699529]
#  [0.2713338 ]
#  [0.39602047]
#  [0.06374443]
#  [0.14326313]
#  [0.2373456 ]
#  [0.12817353]
#  [0.12581575]
#  [0.2834596 ]
#  [0.07118225]
#  [0.24735546]
#  [0.02173525]
#  [0.13736936]
#  [0.15322587]
#  [0.36118716]
#  [0.15135977]
#  [0.00203559]
#  [0.06754074]
#  [0.13068008]
#  [0.06235102]
#  [0.3046056 ]
#  [0.08131331]
#  [0.13883108]
#  [0.06072077]
#  [0.08866698]
#  [0.2598492 ]
#  [0.00203571]
#  [0.19645464]
#  [0.59806657]
#  [0.23204479]
#  [0.3470413 ]
#  [0.24297652]
#  [0.05185819]
#  [0.07626453]
#  [0.24939305]
#  [0.18647042]
#  [0.05375853]
#  [0.40583926]
#  [0.44033512]
#  [0.33539283]
#  [0.13070989]
#  [0.77816904]
#  [0.59863275]
#  [0.13086087]
#  [0.11710387]
#  [0.09123582]
#  [0.04238528]
#  [0.00203538]
#  [0.00212207]
#  [0.4720162 ]
#  [0.06582752]
#  [0.2910189 ]
#  [0.16286176]
#  [0.8407024 ]
#  [0.13357738]
#  [0.19553187]
#  [0.10550475]
#  [0.44123545]
#  [0.33107027]
#  [0.04590514]
#  [0.00203538]
#  [0.00204664]
#  [0.00204089]
#  [0.06683522]
#  [0.14847201]
#  [0.14432639]
#  [0.00228649]
#  [0.2491669 ]
#  [0.738351  ]
#  [0.03353402]
#  [0.20667556]
#  [0.09116107]
#  [0.11592487]
#  [0.08147493]
#  [0.54760164]
#  [0.24564841]
#  [0.2514647 ]
#  [0.37325066]
#  [0.1333797 ]
#  [0.03131512]
#  [0.04800746]
#  [0.15289119]
#  [0.39614552]
#  [0.08306587]
#  [0.77728856]
#  [0.11467862]
#  [0.06716523]
#  [0.09803018]
#  [0.2622955 ]
#  [0.13067418]
#  [0.11644518]]

# %%
top10_df["popularity_predict"] = predictions
top10_df
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year  popularity  popularity_predict
# 0           0.04          97     0.80  2010          83            0.000540
# 1           0.23          87     0.64  2010          82            0.000540
# 2           0.14         120     0.71  2010          80            0.000540
# 3           0.04         119     0.71  2010          79            0.000540
# 4           0.04         109     0.43  2010          78            0.000540
# ..           ...         ...      ...   ...         ...                 ...
# 598         0.03         104     0.16  2019          75            0.996379
# 599         0.12          95     0.61  2019          75            0.977933
# 600         0.34         136     0.65  2019          70            0.995155
# 601         0.07         114     0.24  2019          69            0.968222
# 602         0.06         150     0.23  2019          67            0.992640
#
# [603 rows x 12 columns]

# %% [markdown]
# ### Plotting

# %%
# for i in top10_df['popularity_predict']:
#     if i >= .05:
#         top10df['popular'] = 1
#     elif i < .05:
#         top10df['popular'] = 0
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year  popularity  popularity_predict
# 0           0.04          97     0.80  2010          83            0.000540
# 1           0.23          87     0.64  2010          82            0.000540
# 2           0.14         120     0.71  2010          80            0.000540
# 3           0.04         119     0.71  2010          79            0.000540
# 4           0.04         109     0.43  2010          78            0.000540
# ..           ...         ...      ...   ...         ...                 ...
# 598         0.03         104     0.16  2019          75            0.996379
# 599         0.12          95     0.61  2019          75            0.977933
# 600         0.34         136     0.65  2019          70            0.995155
# 601         0.07         114     0.24  2019          69            0.968222
# 602         0.06         150     0.23  2019          67            0.992640
#
# [603 rows x 12 columns]

# %%
y_axis = top10_df['popularity_predict']
x_axis = top10_df['year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'popularity_predict'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2320/4180117119.py in <module>
# ----> 1 y_axis = top10_df['popularity_predict']
#       2 x_axis = top10_df['year']
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'popularity_predict'

# %%
plt.plot(x_axis, y_axis)
plt.show()

# %%
print(top10_df.loc[[350]])
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 350          0.01          0.68    193000    0.85      0.06        -3
#
#      speechiness  tempo(BPM)  valence  year  popularity
# 350         0.06         127     0.93  2015          50
