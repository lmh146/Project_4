# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Read in the CSV files
top_2019 = pd.read_csv("Resources/cleaned_top10.csv")
decades = pd.read_csv("Resources/bigdf_clean.csv")

# %%
top_2019
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year  popularity
# 0           0.04          97     0.80  2010          83
# ...

# %%
decades
# Out:
#         Unnamed: 0  acousticness  danceability  duration  energy  \
# 0                0        0.9950         0.708    158648  0.1950
# 1                1        0.9940         0.379    282133  0.0135
# 2                2        0.6040         0.749    104300  0.2200
# 3                3        0.9950         0.781    180760  0.1300
# 4                4        0.9900         0.210    687733  0.2040
# ...            ...           ...           ...       ...     ...
# 169904      169904        0.1730         0.875    163800  0.4430
# 169905      169905        0.0167         0.719    167468  0.3850
# 169906      169906        0.5380         0.514    180700  0.5390
# 169907      169907        0.0714         0.646    167308  0.7610
# 169908      169908        0.1090         0.512    214787  0.4280
#
#         instrumentalness  liveness  loudness  popularity  speechiness  \
# 0               0.563000    0.1510   -12.428           0       0.0506
# ...

# %%
# Drop from Big df
big_df = decades.drop(columns = ['Unnamed: 0','instrumentalness'])
big_df
# Out:
#         acousticness  danceability  duration  energy  liveness  loudness  \
# 0             0.9950         0.708    158648  0.1950    0.1510   -12.428
# 1             0.9940         0.379    282133  0.0135    0.0763   -28.454
# 2             0.6040         0.749    104300  0.2200    0.1190   -19.924
# 3             0.9950         0.781    180760  0.1300    0.1110   -14.734
# 4             0.9900         0.210    687733  0.2040    0.0980   -16.829
# ...              ...           ...       ...     ...       ...       ...
# 169904        0.1730         0.875    163800  0.4430    0.0891    -7.461
# 169905        0.0167         0.719    167468  0.3850    0.1110   -10.907
# 169906        0.5380         0.514    180700  0.5390    0.1080    -9.332
# 169907        0.0714         0.646    167308  0.7610    0.2220    -2.557
# 169908        0.1090         0.512    214787  0.4280    0.1050    -7.387
#
#         popularity  speechiness  tempo(BPM)  valence  year
# ...

# %%
# Drop Popularity
top10_df = top_2019.drop(columns = 'popularity')
top10_df
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence  year
# 0           0.04          97     0.80  2010
# ...

# %%
big_df.to_csv('Resources/final_bigdf.csv')

# %%
top10_df.to_csv('Resources/final_top10.csv')

# %%
# Drop Popularity
top10_year_df = top_2019.drop(columns = ['popularity', 'year'])
top10_year_df
# Out:
#      acousticness  danceability  duration  energy  liveness  loudness  \
# 0            0.19          0.67    217000    0.89      0.08        -4
# 1            0.24          0.75    263000    0.93      0.52        -5
# 2            0.10          0.76    200000    0.84      0.29        -3
# 3            0.00          0.70    295000    0.92      0.08        -4
# 4            0.02          0.64    221000    0.84      0.09        -5
# ..            ...           ...       ...     ...       ...       ...
# 598          0.01          0.61    176000    0.66      0.20        -7
# 599          0.21          0.75    206000    0.79      0.07        -6
# 600          0.07          0.53    260000    0.76      0.09        -5
# 601          0.01          0.60    217000    0.79      0.42        -6
# 602          0.06          0.70    213000    0.44      0.13        -9
#
#      speechiness  tempo(BPM)  valence
# 0           0.04          97     0.80
# 1           0.23          87     0.64
# ...

# %%
top10_df.to_csv('Resources/final_top10_no_year.csv')
