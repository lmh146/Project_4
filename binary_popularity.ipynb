# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
file_big = 'Resources/bigdf_clean.csv'
file_small = 'Resources/cleaned_top10.csv'

# %%
train_df = pd.read_csv(file_big)
test_df = pd.read_csv(file_small)

# %%
train_df
# Out:
#         Unnamed: 0  acousticness  danceability  duration  energy  \
# 0                0        0.9950         0.708    158648  0.1950
# 1                1        0.9940         0.379    282133  0.0135
# 2                2        0.6040         0.749    104300  0.2200
# 3                3        0.9950         0.781    180760  0.1300
# 4                4        0.9900         0.210    687733  0.2040
# ...            ...           ...           ...       ...     ...
# 169904      169904        0.1730         0.875    163800  0.4430
# 169905      169905        0.0167         0.719    167468  0.3850
# 169906      169906        0.5380         0.514    180700  0.5390
# 169907      169907        0.0714         0.646    167308  0.7610
# 169908      169908        0.1090         0.512    214787  0.4280
#
#         instrumentalness  liveness  loudness  popularity  speechiness  \
# 0               0.563000    0.1510   -12.428           0       0.0506
# ...

# %%
for x in range(0, len(train_df)):
    if train_df['popularity'][x] <= 50:
        train_df['popularity'][x] = 0
    else:
        train_df['popularity'][x] = 1
# Out:
# /var/folders/xm/0cm_xt5x7jb2w4xm77tf4b0h0000gn/T/ipykernel_87762/465054385.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['popularity'][x] = 0
# /var/folders/xm/0cm_xt5x7jb2w4xm77tf4b0h0000gn/T/ipykernel_87762/465054385.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['popularity'][x] = 1

# %%
train_df
# Out:
#         Unnamed: 0  acousticness  danceability  duration  energy  \
# 0                0        0.9950         0.708    158648  0.1950
# 1                1        0.9940         0.379    282133  0.0135
# 2                2        0.6040         0.749    104300  0.2200
# 3                3        0.9950         0.781    180760  0.1300
# 4                4        0.9900         0.210    687733  0.2040
# ...            ...           ...           ...       ...     ...
# 169904      169904        0.1730         0.875    163800  0.4430
# 169905      169905        0.0167         0.719    167468  0.3850
# 169906      169906        0.5380         0.514    180700  0.5390
# 169907      169907        0.0714         0.646    167308  0.7610
# 169908      169908        0.1090         0.512    214787  0.4280
#
#         instrumentalness  liveness  loudness  popularity  speechiness  \
# 0               0.563000    0.1510   -12.428           0       0.0506
# ...

# %%
train_df.to_csv('Resources/bigdf_binary.csv')
