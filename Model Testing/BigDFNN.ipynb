# %% [markdown]
# ## Preprocessing

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ae4883c-a16e-4282-b311-a427c0134efd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ae4883c-a16e-4282-b311-a427c0134efd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bigdf_clean.csv to bigdf_clean (1).csv

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("bigdf_clean.csv")
application_df
# Out:
#         Unnamed: 0  acousticness                                   artists  \
# 0                0        0.9950                       ['Carl Woitschach']
# 1                1        0.9940  ['Robert Schumann', 'Vladimir Horowitz']
# 2                2        0.6040                   ['Seweryn Goszczyński']
# 3                3        0.9950                      ['Francisco Canaro']
# 4                4        0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']
# ...            ...           ...                                       ...
# 169904      169904        0.1730                    ['DripReport', 'Tyga']
# 169905      169905        0.0167        ['Leon Bridges', 'Terrace Martin']
# 169906      169906        0.5380                     ['Kygo', 'Oh Wonder']
# 169907      169907        0.0714             ['Cash Cash', 'Andy Grammer']
# 169908      169908        0.1090                        ['Ingrid Andress']
#
#         danceability  duration  energy  instrumentalness  liveness  loudness  \
# 0              0.708    158648  0.1950          0.563000    0.1510   -12.428
# 1              0.379    282133  0.0135          0.901000    0.0763   -28.454
# 2              0.749    104300  0.2200          0.000000    0.1190   -19.924
# 3              0.781    180760  0.1300          0.887000    0.1110   -14.734
# 4              0.210    687733  0.2040          0.908000    0.0980   -16.829
# ...              ...       ...     ...               ...       ...       ...
# 169904         0.875    163800  0.4430          0.000032    0.0891    -7.461
# 169905         0.719    167468  0.3850          0.031300    0.1110   -10.907
# 169906         0.514    180700  0.5390          0.002330    0.1080    -9.332
# 169907         0.646    167308  0.7610          0.000000    0.2220    -2.557
# 169908         0.512    214787  0.4280          0.000000    0.1050    -7.387
#
#         popularity  speechiness  tempo(BPM)  valence  year
# 0                0       0.0506     118.469   0.7790  1928
# 1                0       0.0462      83.972   0.0767  1928
# 2                0       0.9290     107.177   0.8800  1928
# 3                0       0.0926     108.003   0.7200  1928
# 4                0       0.0424      62.149   0.0693  1928
# ...            ...          ...         ...      ...   ...
# 169904           1       0.1430     100.012   0.3060  2020
# 169905           1       0.0403     128.000   0.2700  2020
# 169906           1       0.1050     123.700   0.1530  2020
# 169907           1       0.0385     129.916   0.4720  2020
# 169908           1       0.0271      80.588   0.3660  2020
#
# [169909 rows x 14 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(['Unnamed: 0', 'artists'], axis = 1, inplace = True)
application_df
# Out:
#         acousticness  danceability  duration  energy  instrumentalness  \
# 0             0.9950         0.708    158648  0.1950          0.563000
# 1             0.9940         0.379    282133  0.0135          0.901000
# 2             0.6040         0.749    104300  0.2200          0.000000
# 3             0.9950         0.781    180760  0.1300          0.887000
# 4             0.9900         0.210    687733  0.2040          0.908000
# ...              ...           ...       ...     ...               ...
# 169904        0.1730         0.875    163800  0.4430          0.000032
# 169905        0.0167         0.719    167468  0.3850          0.031300
# 169906        0.5380         0.514    180700  0.5390          0.002330
# 169907        0.0714         0.646    167308  0.7610          0.000000
# 169908        0.1090         0.512    214787  0.4280          0.000000
#
#         liveness  loudness  popularity  speechiness  tempo(BPM)  valence  year
# 0         0.1510   -12.428           0       0.0506     118.469   0.7790  1928
# 1         0.0763   -28.454           0       0.0462      83.972   0.0767  1928
# 2         0.1190   -19.924           0       0.9290     107.177   0.8800  1928
# 3         0.1110   -14.734           0       0.0926     108.003   0.7200  1928
# 4         0.0980   -16.829           0       0.0424      62.149   0.0693  1928
# ...          ...       ...         ...          ...         ...      ...   ...
# 169904    0.0891    -7.461           1       0.1430     100.012   0.3060  2020
# 169905    0.1110   -10.907           1       0.0403     128.000   0.2700  2020
# 169906    0.1080    -9.332           1       0.1050     123.700   0.1530  2020
# 169907    0.2220    -2.557           1       0.0385     129.916   0.4720  2020
# 169908    0.1050    -7.387           1       0.0271      80.588   0.3660  2020
#
# [169909 rows x 12 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# acousticness         4714
# artists             33375
# danceability         1232
# duration            50212
# energy               2332
# instrumentalness     5401
# liveness             1741
# loudness            25313
# popularity              2
# speechiness          1628
# tempo(BPM)          84548
# valence              1739
# year                  100
# dtype: int64

# %%
application_df = application_df.dropna()

# %%
# drop rows with name = ravi 
#application_df.filter(application_df.artist !='artist').show()

application_df = application_df.drop(labels=604, axis=0)

# %%
application_df.tail(15)
# Out:
#         acousticness                                   artists  danceability  \
# 169894        0.5920                            ['Noah Cyrus']         0.618
# 169895        0.4950                   ['Goyard Oz', '$IMEON']         0.864
# 169896        0.0274  ['Lil Tjay', 'Sheff G', 'Sleepy Hallow']         0.701
# 169897        0.0220                                ['Future']         0.854
# 169898        0.2540            ['YoungBoy Never Broke Again']         0.506
# 169899        0.3710            ['YoungBoy Never Broke Again']         0.623
# 169900        0.0452                        ['Kelly Clarkson']         0.655
# 169901        0.2640              ['Meek Mill', 'Roddy Ricch']         0.744
# 169902        0.0227           ['Trey Songz', 'Summer Walker']         0.619
# 169903        0.2100                  ['LEGADO 7', 'Junior H']         0.795
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
#         duration  energy  instrumentalness  liveness  loudness  popularity  \
# 169894    190183   0.428          0.000000    0.1920    -8.500           1
# 169895     63784   0.440          0.000000    0.3200   -11.642           1
# 169896    191904   0.645          0.000174    0.3270    -3.084           1
# 169897    201907   0.599          0.000000    0.1730    -7.406           1
# 169898    175339   0.787          0.000000    0.1120    -6.634           1
# 169899    161019   0.721          0.000000    0.1090    -4.584           1
# 169900    216107   0.719          0.000018    0.1090    -7.400           1
# 169901    167845   0.702          0.000000    0.1200    -6.255           1
# 169902    194576   0.719          0.000000    0.0839    -4.111           1
# 169903    218501   0.585          0.000001    0.1120    -4.451           1
# 169904    163800   0.443          0.000032    0.0891    -7.461           1
# 169905    167468   0.385          0.031300    0.1110   -10.907           1
# 169906    180700   0.539          0.002330    0.1080    -9.332           1
# 169907    167308   0.761          0.000000    0.2220    -2.557           1
# 169908    214787   0.428          0.000000    0.1050    -7.387           1
#
#         speechiness  tempo(BPM)  valence  year
# 169894       0.0380     142.021    0.359  2020
# 169895       0.5530     137.086    0.848  2020
# 169896       0.1640     107.955    0.576  2020
# 169897       0.3550     157.031    0.849  2020
# 169898       0.1610      99.956    0.333  2020
# 169899       0.3390     166.637    0.719  2020
# 169900       0.0368     124.034    0.435  2020
# 169901       0.2880      91.885    0.338  2020
# 169902       0.1570      86.036    0.351  2020
# 169903       0.0374      97.479    0.934  2020
# 169904       0.1430     100.012    0.306  2020
# 169905       0.0403     128.000    0.270  2020
# 169906       0.1050     123.700    0.153  2020
# 169907       0.0385     129.916    0.472  2020
# 169908       0.0271      80.588    0.366  2020

# %%
application_df['popularity'] = pd.to_numeric(application_df['popularity'])

# %%
application_df = application_df.reset_index()

# %%
for x in range(0, len(application_df)):
    if application_df['popularity'][x] <= 50:
        application_df['popularity'][x] = 0
    else:
        application_df['popularity'][x] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
artists_count = application_df['artists'].value_counts()
artists_count
# Out:
# ['Эрнест Хемингуэй']                                  1215
# ['Francisco Canaro']                                   938
# ['Эрих Мария Ремарк']                                  781
# ['Ignacio Corsini']                                    620
# ['Frank Sinatra']                                      592
#                                                       ...
# ['Don Omar', 'Zion & Lennox']                            1
# ['Sia', 'Alan Walker']                                   1
# ['Excision', 'Space Laces']                              1
# ['A$AP Mob', 'A$AP Rocky', 'A$AP Twelvyy', 'KEY!']       1
# ['Cash Cash', 'Andy Grammer']                            1
# Name: artists, Length: 33375, dtype: int64

# %%
Names_to_replace = list(artists_count[artists_count<5].index)
Names_to_replace
# Out:
# ["['Johann Christian Bach', 'Concertgebouworkest', 'Eduard van Beinum']",
#  "['Yung Gravy', 'bbno$']",
#  "['Alexander Glazunov', 'Jascha Heifetz', 'London Philharmonic Orchestra', 'Sir John Barbirolli']",
#  "['Eric Weissberg']",
#  '["Old 97\'s"]',
#  "['Ted Neeley']",
#  "['Beartooth']",
#  "['Euge Groove']",
#  "['Rufus Wainwright']",
#  "['Dem Franchize Boyz']",
#  "['LFO']",
#  "['Ronnie Self']",
#  "['The Sunday Manoa']",
#  "['Why Not']",
#  "['Grizzly Bear']",
#  "['Yuji Nomi']",
#  "['Adriana Caselotti']",
#  "['Ronan Keating']",
#  "['Emeli Sandé']",
#  "['McCafferty']",
#  "['Flipper']",
#  "['Sister Rosetta Tharpe', 'Marie Knight', 'Sam Price Trio']",
#  "['Abhram Bhagat']",
#  "['Coleman Hawkins Quartet']",
#  "['Ludo']",
#  "['MadeinTYO']",
#  "['Martin Garrix']",
#  "['Steven Sharp Nelson']",
#  "['Jeff Beck', 'Rod Stewart']",
#  "['Ray Parker Jr.', 'Raydio']",
#  "['Lou Rawls', 'Les McCann Ltd.']",
#  "['Ashford & Simpson', 'James Simpson']",
#  "['Phillip Phillips']",
#  "['Selena y los Dinos']",
#  "['Rebel Souljahz']",
#  "['TheFatRat']",
#  "['Eric Clapton', 'Jon Astley', 'Andy Macpherson']",
#  "['Jason Michael Carroll']",
#  "['Gabriel Fauré', 'Vladimir Horowitz']",
#  "['Slim Thug']",
#  "['Rain Recorders']",
#  "['Trooper']",
#  "['Chanté Moore']",
#  "['Chhabi Banerjee']",
#  "['Antonio Prió']",
#  "['Lion']",
#  "['Claudio Baglioni']",
#  "['Flux Pavilion']",
#  "['Luz Casal']",
#  "['Wolfgang Amadeus Mozart', 'Cecil Aronowitz', 'Amadeus Quartet']",
#  "['Demetri Martin']",
#  "['+44']",
#  "['Benjamin Britten', 'Eugene Ormandy']",
#  "['The System']",
#  "['Igor Stravinsky', 'Soulima Stravinsky']",
#  "['Vanmala']",
#  "['Nacha Pop']",
#  "['Kruder & Dorfmeister']",
#  "['Los Dareyes De La Sierra']",
#  "['Wolfgang Amadeus Mozart', 'Benny Goodman', 'Budapest String Quartet']",
#  "['The Bonzo Dog Band']",
#  "['Yordano']",
#  "['Kittie']",
#  "['Cesária Evora']",
#  "['Cactus']",
#  "['Giuseppe Verdi', 'Orchestra Del Teatro Alla Scala, Milano', 'Tullio Serafin', 'Orchestra Del Teatro Alla Scala Di Milan']",
#  "['Johnny Cash', 'Carl Perkins']",
#  "['Edwin McCain']",
#  "['Hal Ketchum']",
#  "['Victor Cornelius']",
#  "['Avinash Vyas']",
#  "['Dwijen Mukherjee']",
#  "['Memphis May Fire']",
#  "['Pimp C']",
#  "['Gale Garnett']",
#  "['Pimpinela']",
#  "['Rob Bailey & The Hustle Standard']",
#  "['Bikini Kill']",
#  "['Mississippi John Hurt']",
#  "['Josh Gracin']",
#  '["Des\'ree"]',
#  "['Andrew Bird']",
#  "['Marques Houston']",
#  "['Cornelia Otis Skinner']",
#  "['Bob James', 'David Sanborn']",
#  "['Richard Wagner', 'Staatskapelle Berlin', 'Max von Schillings']",
#  "['Abhayapada Chatterjee']",
#  "['Brewer & Shipley']",
#  "['Danzonera La Playa']",
#  "['Ludwig van Beethoven', 'Berliner Philharmoniker', 'Wilhelm Furtwängler']",
#  "['The Jesus Lizard']",
#  "['Thunderstorm']",
#  "['David Lanz']",
#  "['She Wants Revenge']",
#  "['Francesco De Gregori']",
#  '["The Wailin\' Jennys"]',
#  "['The Cover Girls']",
#  "['Scott McKenzie']",
#  "['Patsy Cline', 'Anita Kerr Singers']",
#  "['Jaguares']",
#  "['Wakin Chau']",
#  "['Queen Naija']",
#  "['Los Liricos De Teran']",
#  "['Larry Graham']",
#  "['Kaiser Chiefs']",
#  "['Future Islands']",
#  "['Jimmy Raney', 'Bob Brookmeyer']",
#  "['Roger Creager']",
#  "['Sven-Bertil Taube']",
#  "['John Coltrane', 'Paul Quinichette']",
#  "['King Krule']",
#  "['Ballyhoo!']",
#  "['Peter and the Test Tube Babies']",
#  "['The Dayton Family']",
#  "['Roedelius']",
#  "['Rihanna', 'Mikky Ekko']",
#  "['The Mission']",
#  "['Dark Angel']",
#  "['The Frights']",
#  "['Bill Justis', 'Jerry Reed']",
#  "['Sleigh Bells']",
#  "['Gipsy Kings', 'Jahloul Bouchikhi', 'N. Reyes', 'T. Baliardo']",
#  "['Ivan Dzerzhinsky', 'Paul Robeson Jr.', 'Lawrence Brown']",
#  "['M2M']",
#  "['Whigfield']",
#  "['Amaranthe']",
#  "['Adriano Celentano']",
#  "['Nina']",
#  "['Grandaddy']",
#  "['Tye Tribbett']",
#  "['Johannes Brahms', 'Jascha Heifetz', 'Fritz Reiner', 'Chicago Symphony Orchestra']",
#  "['Hanson']",
#  "['Judah & the Lion']",
#  "['Ja Rule', 'Ashanti']",
#  "['France Joli']",
#  "['Lil Wyte']",
#  "['Dorrough Music']",
#  "['Lara Fabian']",
#  "['Pahola Marino']",
#  "['Claude Barzotti']",
#  "['The Rippingtons', 'Russ Freeman']",
#  "['St. Lucia']",
#  "['Xavier Rudd']",
#  "['Paul McCartney', 'Wings']",
#  "['Mercedes Sosa']",
#  "['Gregorian Chant', 'Choralschola der Wiener Hofburgkapelle', 'Hubert Dopf S.J.']",
#  "['James Blake']",
#  "['Anton Tschechow']",
#  "['The New Lost City Ramblers']",
#  "['Julie Andrews', 'Dick Van Dyke', 'The Pearlie Chorus']",
#  "['Leela Sawant']",
#  "['The Sleep Helpers']",
#  "['Franz Schubert', 'Elly Ney']",
#  "['Blackberry Smoke']",
#  "['Jose Gamboa Ceballos Y Su Orquesta']",
#  "['Macklemore & Ryan Lewis', 'Wanz']",
#  "['Liz Callaway']",
#  "['Flatsound']",
#  "['Beach Fossils']",
#  "['Zendaya']",
#  "['GIT']",
#  "['Joss Stone']",
#  "['Anita Mui']",
#  "['Yellowjackets']",
#  "['Victor Borge']",
#  "['Os Paralamas Do Sucesso']",
#  "['The Band Of Heathens']",
#  "['Bronco El Gigante de America']",
#  "['Ludwig van Beethoven', 'William Kapell', 'Vladimir Golschmann']",
#  "['Super Grupo Colombia']",
#  "['The Three Suns']",
#  "['Gloriana']",
#  "['Julien Clerc']",
#  "['El DeBarge']",
#  "['Alaska Y Dinarama']",
#  "['RuPaul']",
#  "['Jake Bugg']",
#  "['Nelson Ned']",
#  "['Wolfgang Amadeus Mozart', 'Sir Neville Marriner', 'Academy of St. Martin in the Fields', 'Academy of St. Martin in the Fields Chorus', 'Laszlo Heltay']",
#  "['Valdemar Davids']",
#  "['David Lindley']",
#  "['Giuseppe Verdi', 'Fernando Previtali', 'Coro di Roma della RAI', 'Gaetano Riccitelli', 'Orchestra Sinfonica di Roma della RAI']",
#  "['Anna Kendrick']",
#  "['Fred Astaire', 'Audrey Hepburn', 'Kay Thompson']",
#  "['Zayde Wølf']",
#  "['Gondwana']",
#  "['Jeremy Zucker', 'Chelsea Cutler']",
#  "['Pussycat']",
#  "['Buddy Weed']",
#  "['Suraiya', 'Arun Kumar']",
#  "['Alestorm']",
#  "['Son Volt']",
#  "['Onyx']",
#  "['Annie Lennox', 'Heff Moraes']",
#  "['Olle Adolphson']",
#  "['Rita Lee']",
#  "['Francesco Cilea', 'Orchestra di Torino Della RAI', 'Arturo Basile', 'Paolo Silveri']",
#  "['John Frusciante']",
#  "['Bombay Bicycle Club']",
#  "['La Firma']",
#  "['Young MC']",
#  "['Simon Curtis']",
#  "['César Franck', 'Jascha Heifetz', 'Sir John Barbirolli', 'London Philharmonic Orchestra']",
#  "['Tony Williams']",
#  "['M|O|O|N']",
#  "['Buddy Rich And His Sextet']",
#  "['E.E. Cummings']",
#  "['Grupo Bryndis', 'Los Acosta']",
#  "['Richard Elliot']",
#  "['Billy May & His Orchestra']",
#  "['Thelonious Monk', 'Sonny Rollins', 'Ernie Henry']",
#  "['John Williams', 'Skywalker Symphony Orchestra']",
#  "['Jaco Pastorius']",
#  "['Carlota Jaramillo', 'Luis Alberto Valencia']",
#  "['Aaron Carter']",
#  "['Earle Hagen']",
#  "['Tmsoft’s White Noise Sleep Sounds']",
#  "['Dove Cameron']",
#  "['The Tallest Man On Earth']",
#  "['Vulfpeck']",
#  "['Nada Surf']",
#  "['Arun Kumar']",
#  '["Dr. Buzzard\'s Original Savannah Band"]',
#  "['Yehonatan Geffen', 'Yoni Rechter', 'Gidi Gov', 'Yehudit Ravitz', 'David Broza']",
#  "['Nitzer Ebb']",
#  "['Israel Vibration']",
#  "['Rose Tattoo']",
#  "['Miguel Cassina']",
#  "['The Rapture']",
#  "['A Taste Of Honey']",
#  '["Lupita D\'Alessio"]',
#  "['Beautiful Chorus']",
#  "['Levon Helm']",
#  "['Pratima Banerjee']",
#  "['Yoko Ono']",
#  "['Pistol Annies']",
#  "['JFA']",
#  "['Big Mama Thornton']",
#  "['The Rain Library']",
#  "['Rata Blanca']",
#  "['Pastor Troy']",
#  "['Goldfrapp']",
#  "['Lil Wayne', 'Cory Gunz']",
#  "['Tito Rodriguez & His Orchestra']",
#  "['Johnny Rodriguez']",
#  "['2 Chainz']",
#  "['Vasco Rossi']",
#  "['Ying Yang Twins']",
#  "['Negative Approach']",
#  "['Maria Bethânia']",
#  "['Dishwalla']",
#  "['Love Unlimited']",
#  "['Tony Mottola', 'Tom Glazer', 'Dottie Evans']",
#  "['Airplay']",
#  "['Icon For Hire']",
#  "['Best Coast']",
#  "['Jerry Byrd']",
#  "['M.O.P.']",
#  "['Niykee Heaton']",
#  "['Gerry Mulligan', 'Chet Baker']",
#  "['Omara Portuondo']",
#  '["Gigi D\'Agostino"]',
#  "['Rose']",
#  "['Smino']",
#  "['AmaIia Rodriguez', 'Jaime Santos', 'Santos Moreira']",
#  "['Pete Rock']",
#  "['LaBelle']",
#  "['Kurtis Blow']",
#  "['Taproot']",
#  "['Marguerite Duras']",
#  "['Frank Sinatra', 'Duke Ellington']",
#  "['Johannes Brahms', 'London Philharmonic Orchestra']",
#  "['Frances Faye']",
#  "['RADWIMPS']",
#  "['Status Quo']",
#  "['Little Joe & La Familia']",
#  "['Ernie']",
#  "['A Skylit Drive']",
#  "['Junior Brown']",
#  "['Rupert Holmes']",
#  "['Franz Schubert', 'New York Philharmonic', 'Bruno Walter']",
#  "['Hikaru Utada']",
#  "['Will Downing']",
#  "['Os Originais Do Samba']",
#  "['Ariel Rivera']",
#  "['Wun Two']",
#  "['Mohammed Rafi', 'Lata Mangeshkar']",
#  "['T-Bone Walker']",
#  "['Robert Schumann', 'Martha Argerich']",
#  "['Béla Bartók', 'Fritz Reiner']",
#  "['Young M.A']",
#  "['Young Money']",
#  "['Conjunto Rio Grande']",
#  "['The Spill Canvas']",
#  "['Seafret']",
#  "['Jay & The Techniques']",
#  "['Ugly Kid Joe']",
#  "['Chava Alberstein']",
#  "['Charlie']",
#  "['Jamie Foxx']",
#  "['舒芳']",
#  "['Joseph Achron', 'Felix Mendelssohn', 'Jascha Heifetz', 'Unknown Artist']",
#  "['Patrick Doyle', 'Robert Ziegler', 'Tony Hymas']",
#  "['Beat Happening']",
#  "['Los Chavales De España']",
#  "['Christopher Williams']",
#  '[\'Ricardo "Richie" Ray\', \'Bobby Cruz\']',
#  "['D4L']",
#  "['Kim Waters']",
#  "['Quando Rondo']",
#  "['Rebirth Brass Band']",
#  "['Gigi Gryce']",
#  "['Bernard Wright']",
#  "['Jennifer Hudson']",
#  "['Dilated Peoples']",
#  "['Willie Nelson', 'Leon Russell']",
#  "['Solido']",
#  "['Jascha Heifetz', 'Emanuel Bay']",
#  "['Lou Christie']",
#  "['Ludwig van Beethoven', 'Pierre Monteux']",
#  "['Muscadine Bloodline']",
#  "['Wheeler Walker Jr.']",
#  "['Freddie Mercury']",
#  "['David Shire']",
#  "['Andy Griggs']",
#  "['The Montgomery Gospel Trio, The Nashville Quartet, and Guy Carawan']",
#  "['Mother Goose Club']",
#  "['Paul Anka', 'Odia Coates']",
#  "['Laurie Johnson']",
#  "['Mungo Jerry']",
#  "['PAW Patrol']",
#  "['Le Tigre']",
#  "['Charlie Parker Quintet']",
#  "['Healy']",
#  '[\'Lester Young\', \'Harry "Sweets" Edison\']',
#  "['Hugo von Hofmannsthal']",
#  "['Dmitri Shostakovich', 'Arturo Toscanini']",
#  "['Bing Crosby', 'The Andrews Sisters', 'Vic Schoen & His Orchestra']",
#  "['Charity Bailey']",
#  "['Daya']",
#  "['Johannes Brahms', 'Leonard Bernstein', 'New York Philharmonic']",
#  '["Stompin\' Tom Connors"]',
#  "['Texas']",
#  "['The Remains']",
#  "['Los Solitarios']",
#  "['Trade Martin']",
#  "['Snoh Aalegra']",
#  '[\'Andrew Lloyd Webber\', \'Janet Metz\', \'"Joseph And The Amazing Technicolor Dreamcoat" 1992 Canadian Cast\']',
#  "['Kevin Abstract']",
#  "['Toño Escobar Y Sus Locos']",
#  "['Melodyia Music']",
#  "['Ruelle']",
#  "['Ruby And The Romantics']",
#  "['The Vibrators']",
#  "['I See Stars']",
#  "['Regine Velasquez']",
#  "['A. M. Rajah']",
#  "['Felix Mendelssohn', 'Concertgebouworkest', 'Eduard van Beinum']",
#  "['Cass McCombs']",
#  "['Lynn Anderson']",
#  "['Dimitra Ntourali']",
#  "['P. B. Sreenivas']",
#  "['tobi lou']",
#  "['Autoheart']",
#  "['Jon Langston']",
#  "['Gigi Gryce & His Orchestra']",
#  "['Johnny Cash', 'The Carter Family', 'The Statler Brothers', 'Carl Perkins']",
#  "['Banda Pachuco']",
#  "['The Brobecks']",
#  "['Mitch Ryder and The Detroit Wheels']",
#  "['Los Dandys']",
#  "['Alfred Hitchcock']",
#  "['Playa Limbo']",
#  "['Jawbreaker']",
#  "['Chelsea Cutler']",
#  "['Psycoprata', 'SativanderGround']",
#  "['n/a', 'Nitsch, Johannes', 'In Motion']",
#  "['Johann Sebastian Bach', 'Ralph Kirshbaum']",
#  "['Horace Parlan']",
#  "['Huncho Jack', 'Travis Scott', 'Quavo']",
#  "['The Ataris']",
#  "['Beanie Sigel']",
#  "['Diomedes Diaz', 'Juancho Rois']",
#  "['Los Dos Carnales']",
#  "['The Cookies']",
#  "['Charlotte Lawrence']",
#  "['The Lounge Lizards']",
#  "['Los Dinamicos Del Norte']",
#  "['The Go-Betweens']",
#  "['Cradle Of Filth']",
#  "['Godspeed You! Black Emperor']",
#  "['Roy Eldridge', 'Flip Phillips', 'Mel Tormé']",
#  "['Jellyfish']",
#  "['K.Flay']",
#  "['Johann Sebastian Bach', 'Monica Huggett', 'Orchestra of the Age of Enlightenment']",
#  "['Aniceto Molina Y La Luz Roja De San Marcos']",
#  "['DREAMS COME TRUE']",
#  "['Internacional Carro Show']",
#  "['Archers Of Loaf']",
#  "['The Beta Band']",
#  "['Bulletboys']",
#  "['Sizzla']",
#  "['Kotch', 'Sly & Robbie']",
#  "['David Haas']",
#  "['Rodney Carrington']",
#  "['Omar Apollo']",
#  "['Jack Stauber']",
#  "['Summer Salt']",
#  "['Samantha Fox']",
#  "['Si Zentner']",
#  "['Alegre All Stars']",
#  "['DevilDriver']",
#  "['King Von']",
#  "['Leslie Cheung']",
#  "['Jackson Do Pandeiro']",
#  "['Lukas Graham']",
#  "['La Sonora Dinamita']",
#  "['Los Brios']",
#  "['Mike Ryan']",
#  "['Eliseo Robles y los Bárbaros del Norte']",
#  "['Rain Sounds Factory STHLM']",
#  "['Ascharyamoyee Dasi']",
#  "['D-Train']",
#  "['Chantal Kreviazuk']",
#  "['King Radio']",
#  "['Ricky Montgomery']",
#  "['Swans']",
#  "['Tomppabeats']",
#  "['TV Girl']",
#  "['Red Garland Quintet']",
#  "['Destroyer']",
#  "['Dobie Gray']",
#  "['Antonio Vivaldi', 'Isaac Stern', 'Jerusalem Music Center Chamber Orchestra']",
#  "['Andrés Calamaro']",
#  "['Michael Kiwanuka']",
#  "['Gob']",
#  "['Aurra']",
#  "['Grupo Zaaz de Victor Hugo Ruiz']",
#  "['Tyler Farr']",
#  "['Jack Harlow']",
#  "['Lalita Parulekar']",
#  "['David Cassidy', 'The Partridge Family']",
#  "['Russ Morgan and His Orchestra']",
#  "['Sugar']",
#  "['Sergei Rachmaninoff', 'Oscar Levant']",
#  "['The Dirty Dozen Brass Band']",
#  "['Elijah Who']",
#  "['GOT7']",
#  "['Alanis Morissette', 'Christopher Fogel']",
#  "['Greyson Chance']",
#  "['Dru Down']",
#  "['Ever So Blue']",
#  "['SYML']",
#  "['O.C.']",
#  "['Nice & Smooth']",
#  "['Kingdom Come']",
#  "['JAY-Z', 'Memphis Bleek']",
#  "['Lou Gramm']",
#  "['Benny Goodman Quartet']",
#  "['Louie Ramirez']",
#  "['Keith Jarrett', 'Jan Garbarek', 'Palle Danielsson', 'Jon Christensen']",
#  "['Fania All Stars', 'Héctor Lavoe']",
#  "['Robert Schumann', 'Lotte Lehmann']",
#  "['Ja Rule']",
#  "['Stan Bush']",
#  "['Yung Pinch']",
#  "['Entombed']",
#  "['SafetySuit']",
#  "['Cherrelle']",
#  "['Zach Williams']",
#  "['Luiz Gonzaga']",
#  "['George Frideric Handel', 'Jascha Heifetz']",
#  "['Nikki Blonsky']",
#  "['Giacomo Puccini', 'Maria Callas', 'Giuseppe Di Stefano', 'Orchestra Del Teatro Alla Scala, Milano', 'Victor de Sabata']",
#  "['James Cleveland']",
#  "['Johannes Brahms', 'Sir John Barbirolli', 'New York Philharmonic']",
#  "['Semisonic']",
#  "['Slowburner']",
#  "['ABN']",
#  "['Michael Henderson']",
#  "['Whitney']",
#  "['The Lion']",
#  "['Banda Sinaloense MM']",
#  "['DaBaby', 'Roddy Ricch']",
#  "['Ανέστης Δελιάς']",
#  "['The Rivieras']",
#  "['Walter Murphy']",
#  "['Mexicano']",
#  "['Anton Bruckner', 'Berliner Philharmoniker', 'Carl Schuricht']",
#  "['Artie Morris']",
#  "['The Ting Tings']",
#  "['Sir Lancelot']",
#  "['Jonathan Richman', 'The Modern Lovers']",
#  "['Aloe Blacc']",
#  "['John Fogerty']",
#  "['Francisco Canaro', 'Carlos Dante']",
#  "['2Pac', 'Talent']",
#  "['TOMORROW X TOGETHER']",
#  "['Pablo de Sarasate', 'Ossy Renardy']",
#  "['Λαϊκή Ορχήστρα']",
#  "['Jukebox The Ghost']",
#  "['J.L.B. Y Cía']",
#  "['La Quinta Estacion']",
#  "['Rock Projection']",
#  "['Thelonious Monk Orchestra']",
#  "['Benjamin Britten', 'Baltimore Symphony Orchestra', 'Yo-Yo Ma', 'David Zinman']",
#  "['Jim Sturgess']",
#  "['K.R.Ramasamy']",
#  "['Rosemary Clooney', 'Guy Mitchell', 'Joanne Gilbert']",
#  "['Giacomo Puccini', 'Alfredo Simonetto', 'Orchestra Lirica di Torino della Rai']",
#  "['Amanda Perez']",
#  "['Calle 13']",
#  "['Claude Debussy', 'Juilliard String Quartet']",
#  "['John Waite']",
#  "['Teddi King']",
#  "['Margarita Cueto', 'Luis Àlvarez']",
#  "['Vixen']",
#  "['Ben Platt']",
#  "['The Latin Jazz Quintet', 'Eric Dolphy']",
#  "['La Mosca Tse-Tse']",
#  "['Mark Mancina', 'Phil Collins']",
#  "['Gary Hobbs']",
#  "['Banda Española']",
#  "['Grigoris Asikis']",
#  "['Pelle Törner tolkar Evert Taube']",
#  "['Stars Of The Lid']",
#  '["Ramblin\' Jack Elliott"]',
#  "['Surendra', 'Miss Bibbo']",
#  "['Kimya Dawson']",
#  "['Lampros Xalkias']",
#  "['Enrique Granados', 'Andrés Segovia']",
#  "['The Hush Sound']",
#  "['The High Windows']",
#  "['Toby Fox']",
#  "['The Internet']",
#  "['John Mayall & The Bluesbreakers']",
#  "['The Standells']",
#  "['Johannes Brahms', 'Wilhelm Stross', 'Elly Ney', 'Ludwig Hoelscher']",
#  "['JAY-Z', 'Beanie Sigel']",
#  "['Kitaro']",
#  "['Paula Tsui']",
#  "['Dan Fogelberg', 'Tim Weisberg']",
#  "['Cute Is What We Aim For']",
#  "['LSG']",
#  "['Jonathan Coulton']",
#  "['Tink']",
#  "['Yellow Days']",
#  '["Da Vinci\'s Notebook"]',
#  "['Every Time I Die']",
#  "['Lupillo Rivera']",
#  "['Crivel E Coro']",
#  "['Billie Jo Spears']",
#  "['Los Pericos']",
#  "['Sea Wolf']",
#  "['Ghantasala', 'P. Susheela']",
#  "['Devika Rani']",
#  "['Lloyd']",
#  "['Wolfgang Amadeus Mozart', 'Rudolf Serkin', 'George Szell', 'Columbia Symphony Orchestra']",
#  "['Ludwig van Beethoven', 'Staatskapelle Berlin']",
#  "['A R I Z O N A']",
#  "['Silver Convention']",
#  "['Serj Tankian']",
#  "['Bob Dylan', 'Joan Baez']",
#  "['Invisible']",
#  "['Franck Pourcel']",
#  "['Dinendranath Tagore']",
#  "['Cole Porter', 'Alfred Drake', 'Kiss Me, Kate Ensemble', 'Pembroke Davenport', 'Original Broadway Cast Orchestra']",
#  "['Ruff Endz']",
#  "['Don Covay']",
#  "['Fiji']",
#  "['Gramophone Club']",
#  "['Sia', 'Diplo', 'Labrinth', 'LSD']",
#  "['Darude']",
#  "['Sergio Vargas']",
#  "['The Boys']",
#  "['The Slackers']",
#  "['Art Pepper', 'Sonny Redd']",
#  "['Chiodos']",
#  "['Joe Williams', 'Count Basie']",
#  "['Anna Clendening']",
#  "['Franz Schubert', 'Elisabeth Schwarzkopf']",
#  "['Rolando Aguiló y su Orquesta']",
#  '[\'Francis Poulenc\', \'Denise Duval\', "Orch Du Théatre Nat De L\'Opéra", \'Georges Prêtre\', "Orchestre du Théâtre national de l\'Opéra-Comique"]',
#  "['Magneto']",
#  "['Nahko And Medicine For The People']",
#  "['Geeta Dutt', 'Shamshad Begum']",
#  "['Special Ed']",
#  "['Little Dragon']",
#  "['Chhota Gandharva']",
#  "['Modest Mussorgsky', 'Fritz Reiner']",
#  "['Gary Clark Jr.']",
#  "['Sabrina Claudio']",
#  "['Basilio Garcia and Band']",
#  "['Johann Sebastian Bach', 'Catherine Mackintosh/Paul Goodwin/Timothy Brown/Susan Dent/Orchestra of the Age of Enlightenment', 'Orchestra of the Age of Enlightenment']",
#  "['Al Haig Quartet']",
#  "['Anika Noni Rose']",
#  "['Rain Sound Studio']",
#  "['Johnny Clegg', 'Savuka']",
#  "['Alexander Glazunov', 'Jascha Heifetz', 'Walter Hendl', 'RCA Victor Symphony Orchestra']",
#  "['Zack Hemsey']",
#  "['No Vacation']",
#  "['Robert Farnon']",
#  "['Ryan Hurd']",
#  "['Amilcare Ponchielli', 'Maria Callas', 'Antonino Votto', 'Orchestra Sinfonica della RAI de Torino']",
#  "['The Lonely Island']",
#  "['Trio Surdina']",
#  "['lovelytheband']",
#  "['Omega']",
#  "['The Penetraitors']",
#  "['Giacomo Puccini', 'Victor de Sabata', 'Orchestra Del Teatro Alla Scala, Milano']",
#  "['Traditional', 'Norma Procter', 'Alec Redshaw']",
#  "['The Chinese Cultural Theatre Group']",
#  "['Sterling Brown']",
#  "['KYLE', 'Lil Yachty']",
#  "['Wolfgang Amadeus Mozart', 'Elisabeth Schwarzkopf', 'Herbert von Karajan', 'Philharmonia Orchestra']",
#  "['Camille Saint-Saëns', 'Robert Casadesus', 'Artur Rodzinski', 'New York Philharmonic']",
#  "['Roy Haynes']",
#  "['FIDLAR']",
#  "['The Brady Bunch']",
#  "['Djalma Ferreira']",
#  "['Ludwig Satz']",
#  "['Chet Faker']",
#  "['The Irish Rovers']",
#  "['Millie Jackson']",
#  "['Erwin Wickert']",
#  "['Idina Menzel']",
#  "['Maurice Ravel', 'Concertgebouworkest']",
#  "['Alfredo Olivas']",
#  "['George Frideric Handel', 'Isaac Stern']",
#  "['Ermanno Wolf-Ferrari', 'Angelo Questa', 'Orchestra Sinfonica Di Torino Della Rai']",
#  "['Doobie']",
#  "['Anton Bruckner', 'Wiener Philharmoniker', 'Wilhelm Furtwängler']",
#  "['Kota the Friend']",
#  "['Norma Jean']",
#  "['Richard Rodgers', 'Lehman Engel', 'Nelson Eddy', 'Virginia Haskins', 'Portia Nelson']",
#  "['Wade Bowen']",
#  "['Γιώργος Καβούρας']",
#  "['Jack Fascinato']",
#  "['Bedana Dasi']",
#  "['Wolfgang Amadeus Mozart', 'Eugene Ormandy', 'Philadelphia Orchestra']",
#  "['LOCASH']",
#  "['New Orchestral Society of Boston']",
#  "['Riccardo Cocciante']",
#  "['Bob Ross']",
#  "['Stan Getz', 'Chet Baker']",
#  "['Gramatik']",
#  "['Devika Rani', 'Ashok Kumar']",
#  "['Secondhand Serenade']",
#  "['Kausar Parveen']",
#  "['half•alive']",
#  "['Ulices Chaidez']",
#  "['Action Bronson']",
#  "['Peggy Lee', 'George Shearing', 'Ron McMaster']",
#  "['The New Pornographers']",
#  "['Dean Martin', 'Dick Stabile And His Orchestra']",
#  "['Los Armadillos de la Sierra']",
#  "['Mikey Dread']",
#  "['Frightened Rabbit']",
#  "['Raheem DeVaughn']",
#  "['Beirut']",
#  "['Ludwig van Beethoven', 'Jascha Heifetz', 'Arturo Toscanini']",
#  "['Matti Caspi']",
#  "['Bobby Troup']",
#  "['William McDowell']",
#  "['Josh Garrels']",
#  "['Johann Sebastian Bach', 'Pablo Casals', 'Paul Baumgartner']",
#  "['Baby Keem']",
#  "['Gaston Bachelard']",
#  "['Camille Saint-Saëns', 'Jascha Heifetz', 'Brooks Smith']",
#  "['Chuy Lizarraga y Su Banda Tierra Sinaloense']",
#  "['BENEE']",
#  "['Cole Porter', 'Patricia Morison', 'Pembroke Davenport', 'Original Broadway Cast Orchestra']",
#  "['Arsenal Efectivo']",
#  "['IU']",
#  "['Giuseppe Verdi', 'Richard Tucker', 'Nello Santi', 'Vienna State Opera Orchestra']",
#  "['Ashes Remain']",
#  "['Alberto Rabagliati', 'Lecuona Cuban Boys']",
#  "['Julio Chaidez']",
#  "['The Chico Hamilton Quintet', 'Buddy Collette']",
#  "['Richard Strauss', 'Jascha Heifetz']",
#  "['Ila Mitra Ghosh']",
#  "['Grupo Pegasso']",
#  "['Marika Frantzeskopoulou']",
#  "['D.Filipopoulos']",
#  "['Édouard Lalo', 'Jascha Heifetz', 'William Steinberg']",
#  "['Kool Moe Dee']",
#  "['Vertical Horizon']",
#  "['The Astronauts']",
#  "['Martinho Da Vila']",
#  "['Sweet Trip']",
#  "['Dailey & Vincent']",
#  "['Youth Of Today']",
#  "['Jesse Johnson']",
#  "['The Veterinary Street Jazz Band']",
#  "['Rick Trevino']",
#  "['zebrahead']",
#  "['Sugar Chile Robinson']",
#  "['Antonín Dvořák', 'Fritz Reiner', 'Chicago Symphony Orchestra']",
#  "['Stephen Schwartz', 'Kristin Chenoweth', 'Idina Menzel', 'Stephen Oremus', 'Alex Lacamoire']",
#  "['Harimati']",
#  "['Jesse Pearson']",
#  "['Jimmy McGriff']",
#  "['Nuclear Assault']",
#  "['Manole Stroici']",
#  "['Reynaldo Hahn', 'Jacques Jansen', 'Jacqueline Bonneau']",
#  "['Giacomo Puccini', 'Kiri Te Kanawa', 'Sir John Pritchard']",
#  "['Walter Hawkins']",
#  "['Kirk Whalum']",
#  "['Marian Hill']",
#  "['Authority Zero']",
#  "['Wolfgang Amadeus Mozart', 'Elisabeth Schwarzkopf', 'Sir John Pritchard', 'Philharmonia Orchestra']",
#  "['Clipse']",
#  "['Frankie J']",
#  "['Coyote Oldman']",
#  "['Scary Kids Scaring Kids']",
#  "['Wolfgang Amadeus Mozart', 'Capella Istropolitana', 'Wolfgang Sobotka']",
#  "['Kings of Convenience']",
#  "['Spectre General']",
#  "['Newcleus']",
#  "['Les McCann']",
#  "['Carmen Delia Dipini', 'Johnny Rodriguez Y Su Trio']",
#  "['Tadd Dameron Sextet']",
#  "['The Greg Kihn Band']",
#  "['Trans-Siberian Orchestra']",
#  "['Bow Wow Wow']",
#  "['Keith Forsey']",
#  "['Sik World']",
#  "['Ghostface Killah', 'Raekwon', 'Cappadonna']",
#  "['The Yardbirds', 'Eric Clapton']",
#  "['Pyotr Ilyich Tchaikovsky', 'Berliner Philharmoniker']",
#  "['Dimension Latina']",
#  "['Sonny Rollins', 'The Modern Jazz Quartet']",
#  "['Rocío Dúrcal', 'El Mariachi De América De Jesús Rodriguez De Hijar']",
#  "['Jimmy Bryant', 'Speedy West']",
#  "['R. Kelly', 'Public Announcement']",
#  "['Sex Bob-Omb']",
#  "['M. S. Subbulakshmi', 'Radha Vishwanathan']",
#  "['Jeff Williams', 'Casey Lee Williams']",
#  "['Robin Thicke']",
#  "['The Afters']",
#  "['Billie Holiday', 'Sy Oliver & His Orchestra']",
#  "['Robert Schumann', 'Rudolf Serkin']",
#  "['Brazeros Musical De Durango']",
#  "['Los Troqueros']",
#  "['Lee Roy Parnell']",
#  "['The Walkmen']",
#  "['Gloria Lynne']",
#  "['Giuseppe Verdi', 'Maria Callas', 'Milan La Scala Chorus', 'Orchestra Del Teatro Alla Scala, Milano', 'Tullio Serafin']",
#  "['Traditional', 'Mormon Tabernacle Choir', 'Richard P. Condie']",
#  "['RJD2']",
#  "['Wolfgang Amadeus Mozart', 'New York Philharmonic', 'Bruno Walter']",
#  "['Within Temptation']",
#  "['Dilip Kumar']",
#  "['Burton Cummings']",
#  "['AURORA']",
#  "['Nicolette Larson']",
#  "['Atomic Kitten']",
#  "['Josef Strauss', 'Wiener Philharmoniker', 'Clemens Krauss']",
#  '["Dustin O\'Halloran"]',
#  "['World Party']",
#  "['Joan Ellison', 'Jason Aquila', 'Jodie Ricci']",
#  "['No Use For A Name']",
#  "['David Zaizar']",
#  "['Django Reinhardt', 'Grand Orchestre de Danse']",
#  "['Franz Allers']",
#  "['Wolfgang Amadeus Mozart', 'Vladimir Horowitz']",
#  "['Lauv', 'Troye Sivan']",
#  "['Wet Wet Wet']",
#  "['Voodoo Glow Skulls']",
#  '["Original Broadway Cast Of \'Flahooley"]',
#  "['Old Harp Singers of Eastern Tennessee']",
#  "['Richard Wagner', 'Keilberth', 'Varnay', 'Lorenz', 'Uhde', 'Greindl', 'Modl', 'Siewert']",
#  "['Richard Rodgers', 'Frederick Dvonch', 'Mary Martin', 'Patricia Neway', 'Lauri Peters']",
#  "['Petit Biscuit']",
#  "['Madlib']",
#  "['Joe Bushkin & Trio']",
#  "['Bukka White']",
#  "['Julian Cope']",
#  "['Los Cuatro Huasos']",
#  "['Ludwig van Beethoven', 'Arthur Rubinstein', 'Jascha Heifetz', 'Emanuel Feuermann']",
#  "['6ix9ine', 'Nicki Minaj']",
#  '["The La\'s"]',
#  "['Las Jilguerillas']",
#  "['Richard Wagner', 'RIAS-Symphonie-Orchester', 'Ferenc Fricsay', 'RIAS Kammerchor']",
#  "['Edgar Allan Poe']",
#  "['Béla Fleck', 'Sam Bush', 'Jerry Douglas', 'Stuart Duncan', 'Tony Rice', 'Mark Schatz']",
#  "['Rev. Milton Brunson', 'The Thompson Community Singers']",
#  "['50 Cent', 'Young Buck']",
#  "['Peggy Lee', 'Benny Goodman']",
#  "['Lil Nas X']",
#  "['Hemant Kumar', 'Lata Mangeshkar']",
#  "['Glen Campbell', 'The Green River Boys']",
#  "['D.P. Korgaonkar']",
#  "['Zahur Raja']",
#  "['Steve Green']",
#  "['Bashir Qawal']",
#  "['Anima Dasgupta']",
#  "['Yvonne Elliman']",
#  "['Josh Ritter']",
#  "['Mild High Club']",
#  "['Lebo M.']",
#  "['Catfish and the Bottlemen']",
#  "['John Zacherle']",
#  "['Medeski, Martin & Wood']",
#  "['Madhubala Jhaveri']",
#  "['Jay Pérez']",
#  "['Frankie Yankovic']",
#  "['Brigitte Bardot', 'Serge Gainsbourg']",
#  "['Kid Ory', 'Teddy Buckner', 'Pud Brown', 'Lloyd Glenn', 'Julian Davidson', 'Ed Garland', 'Minor Hall', 'Bob McCracken', 'Don Ewell', 'Morty Corb', 'George Probert', 'Alvin Alcorn', 'Barney Kessel', 'Phil Gomez', 'Cedric Haywood', 'Wellman Braud']",
#  "['James Vincent McMorrow']",
#  "['Suzy Delair']",
#  "['Surf Curse']",
#  "['The Format']",
#  "['DERYL DODD']",
#  "['Ian Tyson']",
#  "['Khurshid Bano']",
#  "['Fernando Sor', 'Julio Martinez Oyanguren']",
#  "['Diana Ross', 'Marvin Gaye']",
#  "['Peter Bjorn and John']",
#  "['Jamuna Rani']",
#  "['Richard Wagner', 'Inge Borkh', 'Günther Treptow', 'Hans Hotter', 'Ira Malaniuk', 'Josef Greindl And Astrid Varnay']",
#  "['Tara Bai']",
#  "['Doris Day', 'Les Brown & His Orchestra']",
#  "['Fastway']",
#  "['Stefanie Sun']",
#  '[\'The Original Broadway Cast Of "Of Thee I Sing"\']',
#  "['Pages']",
#  "['Doris Day', 'Gene Nelson', 'The Page Cavanaugh Trio']",
#  "['Home']",
#  "['Frankie Ballard']",
#  "['Tommy Olivencia']",
#  "['R. A. Dvorský', 'Melody Boys']",
#  "['Ananda Shankar']",
#  "['Carmen Miranda', 'Almirante']",
#  "['Exuma']",
#  "['Young Marble Giants']",
#  "['John Lennon', 'The Plastic Ono Band', 'The Flux Fiddlers']",
#  "['Charles Gounod', 'Pierre Monteux']",
#  "['Sharmila Roy Pommot']",
#  "['YK Osiris']",
#  "['Ibrahim Özgür', 'Park Otel Orkestrası']",
#  "['Kanye West', 'JAY-Z', 'Big Sean']",
#  "['Sonny Rollins Quartet']",
#  "['Ralph Tresvant']",
#  "['Harold Melvin & The Blue Notes', 'Sharon Paige']",
#  "['Mighty Diamonds']",
#  "['Big Moe']",
#  "['Knife Party']",
#  "['César Franck', 'Pierre Monteux']",
#  "['Paddy Reilly']",
#  "['Joshua Radin']",
#  "['Cluster', 'Eno']",
#  "['1910 Fruitgum Company']",
#  "['SID']",
#  "['CeCe Winans']",
#  "['101 Strings Orchestra']",
#  "['Julie Andrews', 'Bill Lee', 'Charmian Carr', 'Heather Menzies', 'Nicholas Hammond', 'Duane Chase', 'Angela Cartwright', 'Debbie Turner', 'Kym Karath']",
#  "['Jackie Cusic']",
#  "['First Choice']",
#  "['Lil Boodang']",
#  "['Ric Segreto']",
#  "['Georgie Fame']",
#  "['Moving Pictures']",
#  "['Bobby Goldsboro']",
#  "['Kreator']",
#  "['Louis Hardin', 'Moondog']",
#  "['Paco Aguilera', 'Cuadro Flamenco', 'Lola Flores']",
#  "['Steve Young']",
#  "['Paul McCartney', 'Michael Jackson']",
#  "['The Jimmy Castor Bunch']",
#  "['César Franck', 'Zino Francescatti']",
#  "['Norman Greenbaum']",
#  "['Sarah Vaughan', 'Hal Mooney And His Orchestra']",
#  "['Gigi Gryce - Clifford Brown Sextet']",
#  '[\'Fruko Y Sus Tesos\', \'Wilson "Saoko" Manyoma\']',
#  "['Ντούο Χάρμα']",
#  "['Metro Station']",
#  "['Jazz4Fun']",
#  "['Don Ho']",
#  "['Bad English']",
#  "['Lisa Loeb']",
#  "['Soul For Real']",
#  "['Lulu Santos']",
#  "['Ramin Djawadi']",
#  "['LiSA']",
#  "['Robert Plant', 'Alison Krauss']",
#  "['Bob Mould']",
#  "['Jim Stafford']",
#  "['Grupo Modelo']",
#  '["Terence Trent D\'Arby"]',
#  "['NERO']",
#  "['Pete Seeger', 'The Song Swappers']",
#  "['Climax Blues Band']",
#  "['Paro Devi']",
#  "['Corey Hart']",
#  "['Noah And The Whale']",
#  "['Spawnbreezie']",
#  "['Kathryn Grayson']",
#  "['M.I.A.']",
#  "['Maria Conchita Alonso']",
#  "['Betty Everett']",
#  "['Gym Class Heroes']",
#  "['V.I.C.']",
#  "['Maryline Garcia & Christophe da Silva']",
#  "['Benny Hinn']",
#  "['Hayes Carll']",
#  "['Giuseppe Verdi', 'Richard Tucker', 'Eileen Farrell', 'Fausto Cleva', 'Columbia Symphony Orchestra']",
#  "['C & C Music Factory']",
#  "['Johnny O.']",
#  "['Edoardo Vianello']",
#  "['Grupo Toppaz']",
#  '[\'Claude Debussy\', \'Pierre Mollet\', \'Suzanne Danco\', "L\'Orchestre de la Suisse Romande", \'Ernest Ansermet\']',
#  "['John Butler Trio']",
#  "['Sheila E.']",
#  "['The City of Prague Philharmonic Orchestra']",
#  "['Divinyls']",
#  "['B.o.B']",
#  "['Luigi Boccherini', 'Jascha Heifetz']",
#  "['The Valentinos']",
#  "['Frou Frou']",
#  "['Daniel Santos']",
#  "['Unwritten Law']",
#  "['Peabo Bryson', 'Roberta Flack']",
#  "['Suzy Bogguss']",
#  "['Leonardo Paniagua']",
#  "['Arcangel']",
#  "['STEELHEART']",
#  "['Eminem', 'Nate Dogg']",
#  "['Massiel']",
#  "['Annette Funicello', 'Tommy Sands']",
#  "['Super Cat']",
#  "['Cecil Taylor']",
#  "['Las Chicas Del Can']",
#  "['Drake', 'JAY-Z']",
#  "['Astor Piazzolla']",
#  "['Ben Webster', 'Joe Zawinul']",
#  "['Red Sovine']",
#  "['Johannes Brahms', 'Irmgard Seefried', 'Erik Werba']",
#  '["The Mowgli\'s"]',
#  "['Andrew Belle']",
#  "['Volcano Choir']",
#  "['Costumbre']",
#  "['Barbara Dane']",
#  "['Miles Davis', 'Sonny Rollins', 'Horace Silver', 'Percy Heath', 'Kenny Clarke']",
#  "['The Sweet Inspirations']",
#  "['Charlie Byrd']",
#  "['Rick James', 'Teena Marie']",
#  "['Mantovani']",
#  "['Johnny Colon']",
#  "['Etta James', 'Harvey Fuqua']",
#  "['Bill LaBounty']",
#  "['UMI']",
#  "['Jet']",
#  "['Larry Williams']",
#  "['Frederick Delius', 'Royal Philharmonic Orchestra', 'Sir Thomas Beecham']",
#  "['La Fiebre']",
#  "['Brian Crain']",
#  "['Henry Purcell', 'Astra Desmond']",
#  "['Yasuaki Shimizu']",
#  "['Susan Cadogan']",
#  "['Vanessa Hudgens']",
#  "['Pearl Bailey', 'Mitchell Ayres & Jazz Band']",
#  "['Gene Clark', 'The Gosdin Brothers']",
#  "['Lacuna Coil']",
#  "['The Jets']",
#  "['Omar Ruiz']",
#  "['Billie Holiday', 'The All Star Jam Band']",
#  "['Ken Ashcorp']",
#  "['Bert Jansch', 'John Renbourn']",
#  "['Lord Berners', 'Sir Thomas Beecham', 'Philadelphia Orchestra']",
#  "['Hacken Lee']",
#  "['Johannes Brahms', 'Arthur Rubinstein', 'Jascha Heifetz', 'Emanuel Feuermann']",
#  "['The Tremeloes']",
#  "['Roy Harper']",
#  "['Mountain John']",
#  "['Manuel & The Music Of The Mountains']",
#  "['Suraiya', 'Mohammed Rafi']",
#  "['Hünkar']",
#  "['Los Primos MX']",
#  "['Dee Clark']",
#  '["K\'NAAN"]',
#  "['Camille Saint-Saëns', 'National Symphony Orchestra New York', 'Walter Damrosch']",
#  "['Manju']",
#  "['Arnold Bax', 'Hallé']",
#  "['The Get Up Kids']",
#  "['Félix Mayol']",
#  "['The Great Divide']",
#  "['Haruomi Hosono', 'イエロー・マジック・バンド']",
#  "['Pleasure P']",
#  "['Men Without Hats']",
#  "['Roza Eskenazi', 'Nikos Karakostas', 'Klarino']",
#  "['Robert Jysor']",
#  "['Ibrahim Ferrer']",
#  "['Focus']",
#  '["Whitey Morgan and the 78\'s"]',
#  "['Bijoylal Mukherjee']",
#  "['Guy Mitchell']",
#  "['Francisco Canaro Jazz Band']",
#  "['Haruomi Hosono']",
#  "['Rihanna', 'Drake']",
#  ...]

# %%
# Replace in dataframe
for name in Names_to_replace:
    application_df['artists'] = application_df['artists'].replace(name,"Other")

# Check to make sure binning was successful
application_df['artists'].value_counts()
# Out:
# Other                      40013
# ['Эрнест Хемингуэй']        1215
# ['Francisco Canaro']         938
# ['Эрих Мария Ремарк']        781
# ['Ignacio Corsini']          620
#                            ...
# ['Wicked Lady']                5
# ['Jean-Jacques Perrey']        5
# ['Charlie Wilson']             5
# ['Devendra Banhart']           5
# ['Blackmill']                  5
# Name: artists, Length: 5862, dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
bin_count = application_df['top genre'].value_counts()
bin_count
# Out:
# dance pop                    339
# pop                           60
# canadian pop                  34
# barbadian pop                 15
# boy band                      15
# electropop                    14
# british soul                  11
# big room                      10
# canadian contemporary r&b      9
# neo mellow                     9
# art pop                        8
# complextro                     6
# hip pop                        6
# australian dance               6
# atl hip hop                    5
# australian pop                 5
# edm                            5
# permanent wave                 4
# latin                          4
# hip hop                        4
# colombian pop                  3
# tropical house                 3
# brostep                        2
# downtempo                      2
# electronic trap                2
# belgian edm                    2
# escape room                    2
# folk-pop                       2
# electro                        2
# indie pop                      2
# detroit hip hop                2
# candy pop                      2
# acoustic pop                   2
# canadian hip hop               2
# baroque pop                    2
# celtic rock                    1
# moroccan pop                   1
# contemporary country           1
# chicago rap                    1
# electro house                  1
# australian hip hop             1
# canadian latin                 1
# house                          1
# danish pop                     1
# french indie pop               1
# alaska indie                   1
# irish singer-songwriter        1
# hollywood                      1
# metropopolis                   1
# alternative r&b                1
# Name: top genre, dtype: int64

# %%
list(bin_count[bin_count < 8].index)
# Out:
# ['complextro',
#  'hip pop',
#  'australian dance',
#  'atl hip hop',
#  'australian pop',
#  'edm',
#  'permanent wave',
#  'latin',
#  'hip hop',
#  'colombian pop',
#  'tropical house',
#  'brostep',
#  'downtempo',
#  'electronic trap',
#  'belgian edm',
#  'escape room',
#  'folk-pop',
#  'electro',
#  'indie pop',
#  'detroit hip hop',
#  'candy pop',
#  'acoustic pop',
#  'canadian hip hop',
#  'baroque pop',
#  'celtic rock',
#  'moroccan pop',
#  'contemporary country',
#  'chicago rap',
#  'electro house',
#  'australian hip hop',
#  'canadian latin',
#  'house',
#  'danish pop',
#  'french indie pop',
#  'alaska indie',
#  'irish singer-songwriter',
#  'hollywood',
#  'metropopolis',
#  'alternative r&b']

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(bin_count[bin_count < 8].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['top genre'] = application_df['top genre'].replace(app,"Other")

# Check to make sure binning was successful
application_df['top genre'].value_counts()
# Out:
# dance pop                    339
# Other                         92
# pop                           60
# canadian pop                  34
# barbadian pop                 15
# boy band                      15
# electropop                    14
# british soul                  11
# big room                      10
# neo mellow                     9
# canadian contemporary r&b      9
# art pop                        8
# Name: top genre, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#class_count = application_df['CLASSIFICATION'].value_counts()
#class_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
#plusone = class_count[class_count>1]
#plusone

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count < 800].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
num_app_df = pd.get_dummies(application_df)
num_app_df.head()
# Out:
#    acousticness  danceability  duration  energy  instrumentalness  liveness  \
# 0         0.995         0.708    158648  0.1950             0.563    0.1510
# 1         0.994         0.379    282133  0.0135             0.901    0.0763
# 2         0.604         0.749    104300  0.2200             0.000    0.1190
# 3         0.995         0.781    180760  0.1300             0.887    0.1110
# 4         0.990         0.210    687733  0.2040             0.908    0.0980
#
#    loudness  popularity  speechiness  tempo(BPM)  valence  year
# 0   -12.428           0       0.0506     118.469   0.7790  1928
# 1   -28.454           0       0.0462      83.972   0.0767  1928
# 2   -19.924           0       0.9290     107.177   0.8800  1928
# 3   -14.734           0       0.0926     108.003   0.7200  1928
# 4   -16.829           0       0.0424      62.149   0.0693  1928

# %%
# Split our preprocessed data into our features and target arrays
y = num_app_df['popularity']
X = num_app_df.drop(['popularity'], axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim= number_input_features, name = 'layer1')) 

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=18, activation="relu", name = 'layer2'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation="tanh", name = 'layer3'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid")) 

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 20)                240
#
#  layer2 (Dense)              (None, 18)                378
#
#  layer3 (Dense)              (None, 10)                190
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 819
# Trainable params: 819
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Create a callback that saves the model's weights every 5 epochs
callback = tf.keras.callbacks.ModelCheckpoint(filepath = "Models/weights.{epoch:05d}.hdf5", save_freg = "epoch", period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 3983/3983 [==============================] - 8s 2ms/step - loss: 0.3157 - accuracy: 0.8633
# Epoch 2/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2974 - accuracy: 0.8720
# Epoch 3/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2939 - accuracy: 0.8728
# Epoch 4/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2917 - accuracy: 0.8732
# Epoch 5/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2905 - accuracy: 0.8737
# Epoch 6/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2896 - accuracy: 0.8744
# Epoch 7/100
# 3983/3983 [==============================] - 8s 2ms/step - loss: 0.2891 - accuracy: 0.8745
# Epoch 8/100
# 3983/3983 [==============================] - 8s 2ms/step - loss: 0.2889 - accuracy: 0.8744
# Epoch 9/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2882 - accuracy: 0.8745
# Epoch 10/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2879 - accuracy: 0.8743
# Epoch 11/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2877 - accuracy: 0.8749
# Epoch 12/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2876 - accuracy: 0.8748
# Epoch 13/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2874 - accuracy: 0.8746
# Epoch 14/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2871 - accuracy: 0.8750
# Epoch 15/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2868 - accuracy: 0.8750
# Epoch 16/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2870 - accuracy: 0.8744
# Epoch 17/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2867 - accuracy: 0.8751
# Epoch 18/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2868 - accuracy: 0.8746
# Epoch 19/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2865 - accuracy: 0.8754
# Epoch 20/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2864 - accuracy: 0.8754
# Epoch 21/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2863 - accuracy: 0.8746
# Epoch 22/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2863 - accuracy: 0.8745
# Epoch 23/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2862 - accuracy: 0.8756
# Epoch 24/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2861 - accuracy: 0.8750
# Epoch 25/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2860 - accuracy: 0.8754
# Epoch 26/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2857 - accuracy: 0.8754
# Epoch 27/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2860 - accuracy: 0.8747
# Epoch 28/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2857 - accuracy: 0.8753
# Epoch 29/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2856 - accuracy: 0.8753
# Epoch 30/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2855 - accuracy: 0.8750
# Epoch 31/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2855 - accuracy: 0.8751
# Epoch 32/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2854 - accuracy: 0.8753
# Epoch 33/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2855 - accuracy: 0.8750
# Epoch 34/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2854 - accuracy: 0.8751
# Epoch 35/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2851 - accuracy: 0.8752
# Epoch 36/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2850 - accuracy: 0.8759
# Epoch 37/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2852 - accuracy: 0.8754
# Epoch 38/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2852 - accuracy: 0.8753
# Epoch 39/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2849 - accuracy: 0.8751
# Epoch 40/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2850 - accuracy: 0.8746
# Epoch 41/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2848 - accuracy: 0.8750
# Epoch 42/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2848 - accuracy: 0.8749
# Epoch 43/100
# 3983/3983 [==============================] - 8s 2ms/step - loss: 0.2847 - accuracy: 0.8749
# Epoch 44/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2845 - accuracy: 0.8756
# Epoch 45/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2846 - accuracy: 0.8749
# Epoch 46/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2844 - accuracy: 0.8753
# Epoch 47/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2844 - accuracy: 0.8753
# Epoch 48/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2844 - accuracy: 0.8754
# Epoch 49/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2842 - accuracy: 0.8758
# Epoch 50/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2843 - accuracy: 0.8753
# Epoch 51/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2843 - accuracy: 0.8758
# Epoch 52/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2841 - accuracy: 0.8754
# Epoch 53/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2842 - accuracy: 0.8754
# Epoch 54/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2839 - accuracy: 0.8754
# Epoch 55/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2841 - accuracy: 0.8750
# Epoch 56/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2838 - accuracy: 0.8751
# Epoch 57/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2838 - accuracy: 0.8754
# Epoch 58/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2838 - accuracy: 0.8752
# Epoch 59/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2838 - accuracy: 0.8755
# Epoch 60/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2836 - accuracy: 0.8765
# Epoch 61/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2834 - accuracy: 0.8751
# Epoch 62/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2833 - accuracy: 0.8754
# Epoch 63/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2832 - accuracy: 0.8753
# Epoch 64/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2831 - accuracy: 0.8755
# Epoch 65/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2830 - accuracy: 0.8755
# Epoch 66/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2830 - accuracy: 0.8755
# Epoch 67/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2829 - accuracy: 0.8761
# Epoch 68/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2829 - accuracy: 0.8759
# Epoch 69/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2828 - accuracy: 0.8756
# Epoch 70/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2826 - accuracy: 0.8758
# Epoch 71/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2826 - accuracy: 0.8762
# Epoch 72/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2825 - accuracy: 0.8760
# Epoch 73/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2825 - accuracy: 0.8759
# Epoch 74/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2824 - accuracy: 0.8755
# Epoch 75/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2827 - accuracy: 0.8755
# Epoch 76/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2824 - accuracy: 0.8760
# Epoch 77/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2824 - accuracy: 0.8760
# Epoch 78/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2823 - accuracy: 0.8761
# Epoch 79/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2822 - accuracy: 0.8756
# Epoch 80/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2822 - accuracy: 0.8756
# Epoch 81/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2822 - accuracy: 0.8759
# Epoch 82/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2822 - accuracy: 0.8761
# Epoch 83/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2823 - accuracy: 0.8760
# Epoch 84/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2821 - accuracy: 0.8758
# Epoch 85/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2823 - accuracy: 0.8759
# Epoch 86/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2820 - accuracy: 0.8757
# Epoch 87/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2820 - accuracy: 0.8759
# Epoch 88/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2822 - accuracy: 0.8757
# Epoch 89/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2818 - accuracy: 0.8759
# Epoch 90/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2818 - accuracy: 0.8760
# Epoch 91/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2819 - accuracy: 0.8757
# Epoch 92/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2818 - accuracy: 0.8759
# Epoch 93/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2816 - accuracy: 0.8759
# Epoch 94/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2817 - accuracy: 0.8760
# Epoch 95/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2817 - accuracy: 0.8757
# Epoch 96/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2816 - accuracy: 0.8756
# Epoch 97/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2816 - accuracy: 0.8756
# Epoch 98/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2818 - accuracy: 0.8760
# Epoch 99/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2815 - accuracy: 0.8762
# Epoch 100/100
# 3983/3983 [==============================] - 7s 2ms/step - loss: 0.2817 - accuracy: 0.8761

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1328/1328 - 2s - loss: 0.2899 - accuracy: 0.8742 - 2s/epoch - 1ms/step
# Loss: 0.2898786962032318, Accuracy: 0.8741937279701233

# %%
# Export our model to HDF5 file
nn.save('BigDataModel.h5')
from google.colab import files
files.download('BigDataModel.h5')
